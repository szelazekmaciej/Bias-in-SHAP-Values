# %%
import os
import pickle
import pandas as pd
    
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# directory of CSV files
shap_directory = "/home/guillen/Conference Paper SHAP Maciej actualizado/Satimage/shap"

parquet_directory = "/home/guillen/Conference Paper SHAP Maciej actualizado/Satimage/shap"

scoringResults_directory = ""

# %% [markdown]
# sorted_orderScore = pd.DataFrame()

# %%
sorted_orderScore = []

# %%
sorted_orderScore = pd.read_csv(scoringResults_directory+"shap_orderScore_lr.csv")

# %%
sorted_orderScore.drop("Unnamed: 0",axis=1,inplace = True)

# %%
sorted_orderScore
# Out:
#          imbalanceRatio                       Subset  Indicator  \
# 0     lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19  orderMean
# 1     lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19   orderStd
# 2     lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19   orderSum
# 3     lr_shap_list_ir_3  lr_shap_list_ir_3_subset_39  orderMean
# 4     lr_shap_list_ir_3  lr_shap_list_ir_3_subset_39   orderStd
# ...                 ...                          ...        ...
# 1525  lr_shap_list_ir_4  lr_shap_list_ir_4_subset_76   orderStd
# 1526  lr_shap_list_ir_4  lr_shap_list_ir_4_subset_76   orderSum
# 1527  lr_shap_list_ir_2  lr_shap_list_ir_2_subset_88  orderMean
# 1528  lr_shap_list_ir_2  lr_shap_list_ir_2_subset_88   orderStd
# 1529  lr_shap_list_ir_2  lr_shap_list_ir_2_subset_88   orderSum
#
#                                         Sorted_Features
# 0     ['F12attr', 'B14attr', 'D4attr', 'F18attr', 'C...
# 1     ['B14attr', 'F12attr', 'F18attr', 'D4attr', 'B...
# 2     ['F12attr', 'B14attr', 'D4attr', 'F18attr', 'C...
# 3     ['D4attr', 'F12attr', 'D22attr', 'E11attr', 'B...
# 4     ['D4attr', 'F12attr', 'D22attr', 'E11attr', 'B...
# ...                                                 ...
# 1525  ['F18attr', 'D28attr', 'F12attr', 'D4attr', 'E...
# 1526  ['F18attr', 'D28attr', 'F12attr', 'D4attr', 'E...
# 1527  ['F12attr', 'B14attr', 'F18attr', 'B2attr', 'D...
# 1528  ['F12attr', 'B14attr', 'F18attr', 'B2attr', 'D...
# 1529  ['F12attr', 'B14attr', 'F18attr', 'B2attr', 'D...
#
# [1530 rows x 4 columns]

# %%
sorted_orderScore["Sorted_Features"][0]
# Out:
# "['F12attr', 'B14attr', 'D4attr', 'F18attr', 'C15attr', 'B20attr', 'E11attr', 'A25attr', 'D28attr', 'Dattr', 'C21attr', 'B2attr', 'D16attr', 'A13attr', 'A19attr', 'F6attr', 'F30attr', 'A7attr', 'F24attr', 'Fattr', 'D10attr', 'D22attr', 'Eattr', 'E5attr', 'Battr', 'B8attr', 'Aattr', 'E17attr', 'E29attr', 'A1attr', 'C3attr', 'Cattr', 'E23attr', 'B26attr', 'C9attr', 'C27attr']"

# %% [markdown]
# ## Max density values
#
# SHAP value for max KDE (for each feature) - to change, right now its max bar from histogram, a bit generalized maxShap

# %%
maxDensityValues = pd.read_csv(scoringResults_directory+"shap_maxDensityValues_lr.csv")
maxDensityValues.drop("Unnamed: 0",axis=1,inplace = True)

# %%
maxDensityValues[:10]
# Out:
#       imbalanceRatio                       Subset feature        Indicator  \
# 0  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19   Aattr   localMax_Aattr
# 1  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19   Battr   localMax_Battr
# 2  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19   Cattr   localMax_Cattr
# 3  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19   Dattr   localMax_Dattr
# 4  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19   Eattr   localMax_Eattr
# 5  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19   Fattr   localMax_Fattr
# 6  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19  A1attr  localMax_A1attr
# 7  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19  B2attr  localMax_B2attr
# 8  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19  C3attr  localMax_C3attr
# 9  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19  D4attr  localMax_D4attr
#
#       freq1     freq2     freq3
# 0  0.055547  0.088728  0.188269
# 1 -0.165711 -0.052718  0.003778
# 2 -0.034056  0.090121  0.040450
# 3 -0.000923  0.222527 -0.224374
# 4  0.141390  0.201647  0.322162
# 5  0.136356 -0.010232  0.209650
# 6 -0.009752  0.102601  0.018336
# 7  0.017045  0.576649  0.203580
# 8 -0.036726 -0.058053  0.027254
# 9  0.432350 -0.394009  0.156897

# %%
maxDensityValues.columns
# Out:
# Index(['imbalanceRatio', 'Subset', 'feature', 'Indicator', 'freq1', 'freq2',
#        'freq3'],
#       dtype='object')

# %%
maxDensityValues[['imbalanceRatio', 'feature', 'freq1']]
# Out:
#           imbalanceRatio  feature     freq1
# 0      lr_shap_list_ir_5    Aattr  0.055547
# 1      lr_shap_list_ir_5    Battr -0.165711
# 2      lr_shap_list_ir_5    Cattr -0.034056
# 3      lr_shap_list_ir_5    Dattr -0.000923
# 4      lr_shap_list_ir_5    Eattr  0.141390
# ...                  ...      ...       ...
# 18355  lr_shap_list_ir_2  B26attr -0.542338
# 18356  lr_shap_list_ir_2  C27attr -0.004698
# 18357  lr_shap_list_ir_2  D28attr  0.147785
# 18358  lr_shap_list_ir_2  E29attr -0.153598
# 18359  lr_shap_list_ir_2  F30attr  0.073386
#
# [18360 rows x 3 columns]

# %%
# Group by 'imbalanceRatio' and compute statistics for 'freq1'
freq1Statistics = (
    maxDensityValues.groupby(["imbalanceRatio", 'feature'])
    .agg(
        median=("freq1", "median"),
        mean=("freq1", "mean"),
        std=("freq1", "std"),
        iqr=("freq1", lambda x: x.quantile(0.75) - x.quantile(0.25)),
    )
)

# %%
freq1Statistics.reset_index(inplace=True)

# %%
df_melted = freq1Statistics.melt(id_vars=["imbalanceRatio"], var_name="Statistic", value_name="Value")

# %%
# Reset index to prepare for plotting
df_reset = freq1Statistics

# Plotting the dotted chart
plt.figure(figsize=(12, 6))
for ir in df_reset["imbalanceRatio"].unique():
    subset = df_reset[df_reset["imbalanceRatio"] == ir]
#     plt.scatter(subset["feature"], subset["median"], label=f"{ir} (median)", alpha=0.7)  # median chart
    plt.scatter(subset["feature"], subset["mean"], label=f"{ir} (mean)", alpha=0.7)  # mean chart
#     plt.scatter(subset["feature"], subset["std"], label=f"{ir} (std)", alpha=0.7)  # std chart
#     plt.scatter(subset["feature"], subset["iqr"], label=f"{ir} (iqr)", alpha=0.7)  # iqr chart

plt.xticks(rotation=90)
plt.title("Dotted Chart for mean by Imbalance Ratio")
plt.ylabel("Values")
plt.xlabel("Features")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
# Reset index to prepare for plotting
df_reset = freq1Statistics.reset_index()

# Plotting the dotted chart
plt.figure(figsize=(12, 6))
for ir in df_reset["imbalanceRatio"].unique():
    subset = df_reset[df_reset["imbalanceRatio"] == ir]
#     plt.scatter(subset["feature"], subset["median"], label=f"{ir} (median)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["mean"], label=f"{ir} (mean)", alpha=0.7)
    plt.scatter(subset["feature"], subset["std"], label=f"{ir} (std)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["iqr"], label=f"{ir} (iqr)", alpha=0.7)

plt.xticks(rotation=90)
plt.title("Dotted Chart for STD by Imbalance Ratio")
plt.ylabel("Values")
plt.xlabel("Features")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# IR1 - 2%
# IR2 - 5%
# IR5 - 20%
#
# -- STD results are proportional/similar to IQR
# -- Lower Imbalance ratio, the model provides better consistency regarding XAI results. STD is 2x lower than for IR 1
#     -- it is true especially for the most important features, these one have the most differences between the IR
#
# -- If the mean is similar between IR, and std is different. It means that model is aiming at the same values, hovewer is getting more confused/mistaken with growing IR

# %% [markdown]
# ***
# ***
# ***
# ## Mean SHAP

# %%
sorted_orderValuesScore = []
sorted_orderValuesScore = pd.read_csv(scoringResults_directory+"sorted_orderValuesScore_lr.csv")
sorted_orderValuesScore.drop("Unnamed: 0",axis=1,inplace = True)
sorted_orderValuesScore.columns = ['feature', 'shapMean', 'shapStd', 'shapSum', 'subset', 'imbalance_ratio']

# %%
sorted_orderValuesScore
# Out:
#        feature  shapMean   shapStd      shapSum                       subset  \
# 0        Aattr  0.120204  0.083470   300.509261  lr_shap_list_ir_5_subset_19
# 1        Battr  0.164499  0.131331   411.246859  lr_shap_list_ir_5_subset_19
# 2        Cattr  0.076243  0.048371   190.606929  lr_shap_list_ir_5_subset_19
# 3        Dattr  0.487964  0.437843  1219.909976  lr_shap_list_ir_5_subset_19
# 4        Eattr  0.231658  0.162432   579.146074  lr_shap_list_ir_5_subset_19
# ...        ...       ...       ...          ...                          ...
# 18355  B26attr  0.461692  0.399710  1154.229712  lr_shap_list_ir_2_subset_88
# 18356  C27attr  0.018853  0.014565    47.132462  lr_shap_list_ir_2_subset_88
# 18357  D28attr  0.366316  0.256388   915.789142  lr_shap_list_ir_2_subset_88
# 18358  E29attr  0.120273  0.071216   300.682952  lr_shap_list_ir_2_subset_88
# 18359  F30attr  0.069958  0.060194   174.895070  lr_shap_list_ir_2_subset_88
#
#          imbalance_ratio
# 0      lr_shap_list_ir_5
# 1      lr_shap_list_ir_5
# 2      lr_shap_list_ir_5
# 3      lr_shap_list_ir_5
# 4      lr_shap_list_ir_5
# ...                  ...
# 18355  lr_shap_list_ir_2
# 18356  lr_shap_list_ir_2
# 18357  lr_shap_list_ir_2
# 18358  lr_shap_list_ir_2
# 18359  lr_shap_list_ir_2
#
# [18360 rows x 6 columns]

# %%
# Group by 'imbalanceRatio' and compute statistics for 'shapMean'
meanStatistics = (
    sorted_orderValuesScore.groupby(["imbalance_ratio", 'feature'])
    .agg(
        median=("shapMean", "median"),
        mean=("shapMean", "mean"),
        std=("shapMean", "std"),
        iqr=("shapMean", lambda x: x.quantile(0.75) - x.quantile(0.25)),
    )
)
meanStatistics.reset_index(inplace=True)

# %%
meanStatistics[:5]
# Out:
#      imbalance_ratio  feature    median      mean       std       iqr
# 0  lr_shap_list_ir_1  A13attr  0.574408  0.746388  0.588764  0.587252
# 1  lr_shap_list_ir_1  A19attr  0.591026  0.707591  0.560426  0.723434
# 2  lr_shap_list_ir_1   A1attr  0.744131  0.840872  0.709088  1.031309
# 3  lr_shap_list_ir_1  A25attr  0.672763  0.750655  0.597314  0.750781
# 4  lr_shap_list_ir_1   A7attr  0.717906  0.877045  0.645932  0.938671

# %%
# Reset index to prepare for plotting
df_reset = meanStatistics

# Plotting the dotted chart
plt.figure(figsize=(12, 6))
for ir in df_reset["imbalance_ratio"].unique():
    subset = df_reset[df_reset["imbalance_ratio"] == ir]
#     plt.scatter(subset["feature"], subset["median"], label=f"{ir} (median)", alpha=0.7)  # median chart
    plt.scatter(subset["feature"], subset["mean"], label=f"{ir} (mean)", alpha=0.7)  # mean chart
#     plt.scatter(subset["feature"], subset["std"], label=f"{ir} (std)", alpha=0.7)  # std chart
#     plt.scatter(subset["feature"], subset["iqr"], label=f"{ir} (iqr)", alpha=0.7)  # iqr chart

plt.xticks(rotation=90)
plt.title("Dotted Chart for mean by Imbalance Ratio")
plt.ylabel("Values")
plt.xlabel("Features")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### t-tests

# %%
import pandas as pd
import scipy.stats as stats
import itertools

# Load your dataset
sorted_orderValuesScore = pd.read_csv("sorted_orderValuesScore_lr.csv")
sorted_orderValuesScore.drop("Unnamed: 0", axis=1, inplace=True)
sorted_orderValuesScore.columns = ['feature', 'shapMean', 'shapStd', 'shapSum', 'subset', 'imbalance_ratio']

# Get unique IRs and features
imbalance_ratios = sorted_orderValuesScore['imbalance_ratio'].unique()
features = sorted_orderValuesScore['feature'].unique()

# Dictionary to store rankings
rankings_dict = {feature: {} for feature in features}

for feature in features:
    # Filter data for the feature
    feature_data = sorted_orderValuesScore[sorted_orderValuesScore['feature'] == feature]

    # Compute mean shapMean per IR
    means = feature_data.groupby('imbalance_ratio')['shapMean'].mean().sort_values(ascending=False)
    
    # Initialize significance matrix
    significance_matrix = pd.DataFrame(1.0, index=imbalance_ratios, columns=imbalance_ratios)

    # Pairwise t-tests
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        group1 = feature_data[feature_data['imbalance_ratio'] == ir1]['shapMean']
        group2 = feature_data[feature_data['imbalance_ratio'] == ir2]['shapMean']
        
        if len(group1) > 1 and len(group2) > 1:  # Ensure enough data
            stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)  # Welch’s t-test
        else:
            p_value = 1  # Assume no difference if insufficient data
        
        # Store p-value
        significance_matrix.loc[ir1, ir2] = p_value
        significance_matrix.loc[ir2, ir1] = p_value

    # Assign initial rankings based on means
    ranking_values = {ir: rank + 1 for rank, ir in enumerate(means.index)}

    # Adjust rankings if no significant differences
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        if significance_matrix.loc[ir1, ir2] >= 0.05:  # No significant difference
            min_rank = min(ranking_values[ir1], ranking_values[ir2])
            ranking_values[ir1] = ranking_values[ir2] = min_rank

    rankings_dict[feature] = ranking_values

# Convert to DataFrame
ranking_table = pd.DataFrame(rankings_dict).T.fillna(0)

sorted_columns = sorted(ranking_table.columns, key=lambda x: int(x.split('_')[-1]))

# Reorder the DataFrame
ranking_table = ranking_table[sorted_columns]

# Function to adjust rankings so that ties do not skip numbers
def adjust_rankings(df):
    adjusted_df = df.copy()
    
    for feature in df.index:
        unique_ranks = sorted(set(df.loc[feature]))  # Get unique ranks in sorted order
        rank_mapping = {old_rank: new_rank + 1 for new_rank, old_rank in enumerate(unique_ranks)}  # Map old ranks to new continuous ranks
        
        # Apply mapping to adjust ranks
        adjusted_df.loc[feature] = df.loc[feature].map(rank_mapping)

    return adjusted_df

# Apply the function to adjust rankings
ranking_table = adjust_rankings(ranking_table)
import ace_tools_open as tools
# Display the updated ranking table
tools.display_dataframe_to_user(name="Adjusted Ranking of the mean by IR for shapMeans", dataframe=ranking_table)
# Out:
# Adjusted Ranking of the mean by IR for shapMeans
# <!--| quarto-html-table-processing: none -->
# <table id="itables_bfcbd71a_1068_4194_bb51_7f4d1bac56ae"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.4 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_bfcbd71a_1068_4194_bb51_7f4d1bac56ae:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>lr_shap_list_ir_1</th>\n      <th>lr_shap_list_ir_2</th>\n      <th>lr_shap_list_ir_3</th>\n      <th>lr_shap_list_ir_4</th>\n      <th>lr_shap_list_ir_5</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Aattr\", 1, 2, 3, 3, 4], [\"Battr\", 1, 2, 3, 3, 4], [\"Cattr\", 1, 2, 3, 4, 5], [\"Dattr\", 1, 2, 3, 3, 3], [\"Eattr\", 1, 2, 3, 4, 4], [\"Fattr\", 1, 2, 3, 3, 4], [\"A1attr\", 1, 2, 3, 4, 5], [\"B2attr\", 1, 2, 3, 3, 3], [\"C3attr\", 1, 2, 3, 4, 5], [\"D4attr\", 1, 2, 2, 2, 3], [\"E5attr\", 1, 2, 3, 3, 4], [\"F6attr\", 1, 2, 3, 3, 4], [\"A7attr\", 1, 2, 3, 3, 4], [\"B8attr\", 1, 2, 3, 4, 5], [\"C9attr\", 1, 2, 3, 4, 5], [\"D10attr\", 1, 2, 3, 4, 4], [\"E11attr\", 1, 2, 2, 2, 3], [\"F12attr\", 1, 2, 2, 2, 3], [\"A13attr\", 1, 2, 3, 3, 4], [\"B14attr\", 1, 2, 2, 2, 2], [\"C15attr\", 1, 2, 3, 3, 3], [\"D16attr\", 1, 2, 3, 3, 4], [\"E17attr\", 1, 2, 3, 4, 5], [\"F18attr\", 1, 2, 2, 2, 3], [\"A19attr\", 1, 2, 2, 2, 2], [\"B20attr\", 1, 2, 3, 3, 4], [\"C21attr\", 1, 2, 3, 4, 4], [\"D22attr\", 1, 2, 3, 4, 4], [\"E23attr\", 1, 2, 3, 4, 5], [\"F24attr\", 1, 2, 3, 4, 5], [\"A25attr\", 1, 2, 3, 4, 4], [\"B26attr\", 1, 2, 3, 4, 5], [\"C27attr\", 1, 2, 3, 3, 4], [\"D28attr\", 1, 2, 2, 2, 3], [\"E29attr\", 1, 2, 3, 3, 4], [\"F30attr\", 1, 2, 3, 3, 3]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
import numpy as np
import matplotlib.pyplot as plt

num_irs = 5
shap_list_labels = [f"lr_shap_list_ir_{j}" for j in range(1, num_irs + 1)]

rank_colors = {1: 'blue', 2: 'green', 3: 'yellow', 4: 'orange', 5: 'red'}
mismatch_color = 'white'  # Color for non-matching ranks

fig, axes = plt.subplots(num_irs, num_irs, figsize=(25, 25))
# Add a general title to the entire plot
fig.suptitle('Concordance Mean Ranking by IR for shapMeans', fontsize=25, fontweight='bold')

num_variables = ranking_table.shape[0]

for i in range(num_irs):
    for j in range(num_irs):
        ax = axes[i, j]

        if j < i:
            ax.axis("off")
            continue

        if i == j:
            values, counts = np.unique(ranking_table.iloc[:, i], return_counts=True)
            colors = [rank_colors[v] for v in values]
        else:
            matching_counts = {rank: 0 for rank in rank_colors.keys()}

            for var in range(num_variables):
                rank_i = ranking_table.iloc[var, i]
                rank_j = ranking_table.iloc[var, j]
                if rank_i == rank_j:
                    matching_counts[rank_i] += 1

            values = [rank for rank, count in matching_counts.items() if count > 0]
            counts = [count / num_variables for rank, count in matching_counts.items() if count > 0]

            mismatch_proportion = 1 - sum(counts)
            if mismatch_proportion > 0:
                values.append(0)
                counts.append(mismatch_proportion)

            colors = [rank_colors.get(v, mismatch_color) for v in values]

        if len(values) > 0:
            ax.pie(counts, labels=None, autopct='%1.1f%%', colors=colors, startangle=90,textprops={'fontsize': 15},pctdistance=1.45)
        else:
            ax.axis("off")

        if j == i:
            ax.set_ylabel(shap_list_labels[i], rotation=0, labelpad=50, fontsize=20, ha='right', va='center')

for ax, col in zip(axes[0], shap_list_labels):
    ax.set_title(col, fontsize=20, pad=30)

handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=15) for color in rank_colors.values()]
handles.append(plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='white', markersize=15))  # Ensure "No Match" appears visible in legend

labels = [f"Rank {k}" for k in rank_colors.keys()] + ["No Match"]
fig.legend(handles, labels, title="Rank Values", loc="lower left", bbox_to_anchor=(0.3, 0.2), fontsize=21, title_fontsize=25)
plt.tight_layout()
plt.show()

# %%
# Reset index to prepare for plotting
df_reset = meanStatistics

# Plotting the dotted chart
plt.figure(figsize=(12, 6))
for ir in df_reset["imbalance_ratio"].unique():
    subset = df_reset[df_reset["imbalance_ratio"] == ir]
#     plt.scatter(subset["feature"], subset["median"], label=f"{ir} (median)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["mean"], label=f"{ir} (mean)", alpha=0.7)
    plt.scatter(subset["feature"], subset["std"], label=f"{ir} (std)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["iqr"], label=f"{ir} (iqr)", alpha=0.7)

plt.xticks(rotation=90)
plt.title("Dotted Chart for STD by Imbalance Ratio")
plt.ylabel("Values")
plt.xlabel("Features")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import scipy.stats as stats
import itertools

# Load the dataset
sorted_orderValuesScore = pd.read_csv("sorted_orderValuesScore_lr.csv")
sorted_orderValuesScore.drop("Unnamed: 0", axis=1, inplace=True)
sorted_orderValuesScore.columns = ['feature', 'shapMean', 'shapStd', 'shapSum', 'subset', 'imbalance_ratio']

# Get unique features and imbalance ratios
features = sorted_orderValuesScore['feature'].unique()
imbalance_ratios = sorted_orderValuesScore['imbalance_ratio'].unique()

# Dictionary to store rankings based on standard deviation of shapMean
rankings_std_dict = {feature: {} for feature in features}

for feature in features:
    # Filter data for the feature
    feature_data = sorted_orderValuesScore[sorted_orderValuesScore['feature'] == feature]

    # Compute std deviation of shapMean per IR
    std_devs = feature_data.groupby('imbalance_ratio')['shapMean'].std().sort_values(ascending=False)
    
    # Initialize significance matrix
    significance_matrix = pd.DataFrame(1.0, index=imbalance_ratios, columns=imbalance_ratios)

    # Pairwise Levene's test for variance comparison
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        group1 = feature_data[feature_data['imbalance_ratio'] == ir1]['shapMean']
        group2 = feature_data[feature_data['imbalance_ratio'] == ir2]['shapMean']
        
        if len(group1) > 1 and len(group2) > 1:  # Ensure enough data
            stat, p_value = stats.levene(group1, group2, center='median')  # Levene’s test
        else:
            p_value = 1  # Assume no difference if insufficient data
        
        # Store p-value
        significance_matrix.loc[ir1, ir2] = p_value
        significance_matrix.loc[ir2, ir1] = p_value

    # Assign initial rankings based on standard deviations
    ranking_values = {ir: rank + 1 for rank, ir in enumerate(std_devs.index)}

    # Adjust rankings if no significant differences
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        if significance_matrix.loc[ir1, ir2] >= 0.05:  # No significant difference
            min_rank = min(ranking_values[ir1], ranking_values[ir2])
            ranking_values[ir1] = ranking_values[ir2] = min_rank

    rankings_std_dict[feature] = ranking_values

# Convert to DataFrame
ranking_std_table = pd.DataFrame(rankings_std_dict).T.fillna(0)

# Reorder the columns based on IR numeric values
sorted_columns = sorted(ranking_std_table.columns, key=lambda x: int(x.split('_')[-1]))
ranking_std_table = ranking_std_table[sorted_columns]

# Function to adjust rankings so that ties do not skip numbers
def adjust_rankings(df):
    adjusted_df = df.copy()
    
    for feature in df.index:
        unique_ranks = sorted(set(df.loc[feature]))  # Get unique ranks in sorted order
        rank_mapping = {old_rank: new_rank + 1 for new_rank, old_rank in enumerate(unique_ranks)}  # Map old ranks to new continuous ranks
        
        # Apply mapping to adjust ranks
        adjusted_df.loc[feature] = df.loc[feature].map(rank_mapping)

    return adjusted_df

# Apply the function to adjust rankings
ranking_std_table = adjust_rankings(ranking_std_table)

# Display the updated ranking table
tools.display_dataframe_to_user(name="Adjusted Ranking of the variance by IR for shapMeans", dataframe=ranking_std_table)
# Out:
# Adjusted Ranking of the variance by IR for shapMeans
# <!--| quarto-html-table-processing: none -->
# <table id="itables_c14d5e05_6ab0_4e55_87bf_725c7569e18d"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.4 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_c14d5e05_6ab0_4e55_87bf_725c7569e18d:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>lr_shap_list_ir_1</th>\n      <th>lr_shap_list_ir_2</th>\n      <th>lr_shap_list_ir_3</th>\n      <th>lr_shap_list_ir_4</th>\n      <th>lr_shap_list_ir_5</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Aattr\", 1, 2, 3, 3, 4], [\"Battr\", 1, 2, 2, 3, 4], [\"Cattr\", 1, 2, 3, 3, 4], [\"Dattr\", 1, 2, 3, 4, 5], [\"Eattr\", 1, 2, 3, 4, 4], [\"Fattr\", 1, 2, 3, 3, 4], [\"A1attr\", 1, 2, 3, 4, 4], [\"B2attr\", 1, 2, 3, 4, 5], [\"C3attr\", 1, 2, 3, 4, 5], [\"D4attr\", 1, 2, 3, 4, 5], [\"E5attr\", 1, 2, 3, 4, 5], [\"F6attr\", 1, 2, 3, 4, 4], [\"A7attr\", 1, 2, 3, 4, 4], [\"B8attr\", 1, 2, 3, 4, 5], [\"C9attr\", 1, 2, 3, 4, 5], [\"D10attr\", 1, 2, 3, 4, 4], [\"E11attr\", 1, 2, 3, 4, 5], [\"F12attr\", 1, 2, 3, 3, 4], [\"A13attr\", 1, 2, 3, 3, 4], [\"B14attr\", 1, 2, 3, 4, 5], [\"C15attr\", 1, 2, 3, 4, 5], [\"D16attr\", 1, 2, 3, 3, 4], [\"E17attr\", 1, 2, 3, 4, 4], [\"F18attr\", 1, 2, 3, 4, 5], [\"A19attr\", 1, 2, 2, 3, 4], [\"B20attr\", 1, 2, 3, 4, 5], [\"C21attr\", 1, 2, 3, 4, 5], [\"D22attr\", 1, 2, 3, 4, 4], [\"E23attr\", 1, 2, 3, 4, 4], [\"F24attr\", 1, 2, 3, 4, 5], [\"A25attr\", 1, 2, 3, 3, 4], [\"B26attr\", 1, 2, 3, 3, 4], [\"C27attr\", 1, 2, 3, 3, 4], [\"D28attr\", 1, 2, 3, 4, 4], [\"E29attr\", 1, 2, 3, 3, 4], [\"F30attr\", 1, 2, 2, 3, 4]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
import numpy as np
import matplotlib.pyplot as plt

num_irs = 5
shap_list_labels = [f"lr_shap_list_ir_{j}" for j in range(1, num_irs + 1)]

rank_colors = {1: 'blue', 2: 'green', 3: 'yellow', 4: 'orange', 5: 'red'}
mismatch_color = 'white'  # Color for non-matching ranks

fig, axes = plt.subplots(num_irs, num_irs, figsize=(25, 25))
# Add a general title to the entire plot
fig.suptitle('Concordance Variance Ranking by IR for shapMeans', fontsize=25, fontweight='bold')

num_variables = ranking_std_table.shape[0]

for i in range(num_irs):
    for j in range(num_irs):
        ax = axes[i, j]

        if j < i:
            ax.axis("off")
            continue

        if i == j:
            values, counts = np.unique(ranking_std_table.iloc[:, i], return_counts=True)
            colors = [rank_colors[v] for v in values]
        else:
            matching_counts = {rank: 0 for rank in rank_colors.keys()}

            for var in range(num_variables):
                rank_i = ranking_std_table.iloc[var, i]
                rank_j = ranking_std_table.iloc[var, j]
                if rank_i == rank_j:
                    matching_counts[rank_i] += 1

            values = [rank for rank, count in matching_counts.items() if count > 0]
            counts = [count / num_variables for rank, count in matching_counts.items() if count > 0]

            mismatch_proportion = 1 - sum(counts)
            if mismatch_proportion > 0:
                values.append(0)
                counts.append(mismatch_proportion)

            colors = [rank_colors.get(v, mismatch_color) for v in values]

        if len(values) > 0:
            ax.pie(counts, labels=None, autopct='%1.1f%%', colors=colors, startangle=90,textprops={'fontsize': 15},pctdistance=1.45)
        else:
            ax.axis("off")

        if j == i:
            ax.set_ylabel(shap_list_labels[i], rotation=0, labelpad=50, fontsize=20, ha='right', va='center')

for ax, col in zip(axes[0], shap_list_labels):
    ax.set_title(col, fontsize=20, pad=30)

handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=15) for color in rank_colors.values()]
handles.append(plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='white', markersize=15))  # Ensure "No Match" appears visible in legend

labels = [f"Rank {k}" for k in rank_colors.keys()] + ["No Match"]
fig.legend(handles, labels, title="Rank Values", loc="lower left", bbox_to_anchor=(0.3, 0.2), fontsize=21, title_fontsize=25)
plt.tight_layout()
plt.show()

# %%
# Reset index to prepare for plotting
df_reset = meanStatistics

# Plotting the dotted chart
plt.figure(figsize=(12, 6))
for ir in df_reset["imbalance_ratio"].unique():
    subset = df_reset[df_reset["imbalance_ratio"] == ir]
#     plt.scatter(subset["feature"], subset["median"], label=f"{ir} (median)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["mean"], label=f"{ir} (mean)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["std"], label=f"{ir} (std)", alpha=0.7)
    plt.scatter(subset["feature"], subset["iqr"], label=f"{ir} (iqr)", alpha=0.7)

plt.xticks(rotation=90)
plt.title("Dotted Chart for IQR by Imbalance Ratio")
plt.ylabel("Values")
plt.xlabel("Features")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
#Not Working at all
import pandas as pd
import numpy as np
import itertools
from scipy.special import factorial

# Load the dataset
sorted_orderValuesScore = pd.read_csv("sorted_orderValuesScore_lr.csv")
sorted_orderValuesScore.drop("Unnamed: 0", axis=1, inplace=True)
sorted_orderValuesScore.columns = ['feature', 'shapMean', 'shapStd', 'shapSum', 'subset', 'imbalance_ratio']

# Get unique features and imbalance ratios
features = sorted_orderValuesScore['feature'].unique()
imbalance_ratios = sorted_orderValuesScore['imbalance_ratio'].unique()

# Function: Westenberg-Mood Test for IQR Equality
def westenberg_mood_test(x, y):
    x, y = np.array(x), np.array(y)
    if len(x) < 2 or len(y) < 2:
        return 1  # If not enough data, assume no difference

    # Center the data by subtracting the median
    x_centered, y_centered = x - np.median(x), y - np.median(y)

    # Compute IQR (25th-75th percentiles) from the combined data
    combined = np.concatenate([x_centered, y_centered])
    q1, q3 = np.percentile(combined, [25, 75])

    # Count values inside and outside the IQR
    a, b = np.sum((q1 < x_centered) & (x_centered < q3)), len(x) - np.sum((q1 < x_centered) & (x_centered < q3))
    c, d = np.sum((q1 < y_centered) & (y_centered < q3)), len(y) - np.sum((q1 < y_centered) & (y_centered < q3))

    # Contingency table
    m = np.array([[a, c], [b, d]])

    # Compute the p-value
    numer = np.sum(np.log(factorial(m.sum(axis=1)))) + np.sum(np.log(factorial(m.sum(axis=0))))
    denom = np.sum(np.log(factorial(m.flatten()))) + np.log(factorial(m.sum()))
    p_value = 2 * np.exp(numer - denom)

    return p_value

# Dictionary to store rankings based on IQR comparison using the Westenberg-Mood test
rankings_iqr_dict = {feature: {} for feature in features}

for feature in features:
    # Filter data for the feature
    feature_data = sorted_orderValuesScore[sorted_orderValuesScore['feature'] == feature]

    # Compute IQR per IR
    iqr_values = feature_data.groupby('imbalance_ratio')['shapMean'].apply(lambda x: x.quantile(0.75) - x.quantile(0.25)).sort_values(ascending=False)
    
    # Initialize significance matrix
    significance_matrix = pd.DataFrame(1.0, index=imbalance_ratios, columns=imbalance_ratios)

    # Apply the Westenberg-Mood test for IQR comparison
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        group1 = feature_data[feature_data['imbalance_ratio'] == ir1]['shapMean']
        group2 = feature_data[feature_data['imbalance_ratio'] == ir2]['shapMean']
        
        if len(group1) > 1 and len(group2) > 1:  # Ensure sufficient data
            p_value = westenberg_mood_test(group1, group2)
        else:
            p_value = 1  # Assume no difference if insufficient data
        
        # Store p-value
        significance_matrix.loc[ir1, ir2] = p_value
        significance_matrix.loc[ir2, ir1] = p_value

    # Assign initial rankings based on IQR values
    ranking_values = {ir: rank + 1 for rank, ir in enumerate(iqr_values.index)}

    # Adjust rankings if no significant differences
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        if significance_matrix.loc[ir1, ir2] >= 0.05:  # No significant difference
            min_rank = min(ranking_values[ir1], ranking_values[ir2])
            ranking_values[ir1] = ranking_values[ir2] = min_rank

    rankings_iqr_dict[feature] = ranking_values

# Convert to DataFrame
ranking_iqr_table = pd.DataFrame(rankings_iqr_dict).T.fillna(0)

# Reorder the columns based on IR numeric values
sorted_columns = sorted(ranking_iqr_table.columns, key=lambda x: int(x.split('_')[-1]))
ranking_iqr_table = ranking_iqr_table[sorted_columns]

# Function to adjust rankings so that ties do not skip numbers
def adjust_rankings(df):
    adjusted_df = df.copy()
    
    for feature in df.index:
        unique_ranks = sorted(set(df.loc[feature]))  # Get unique ranks in sorted order
        rank_mapping = {old_rank: new_rank + 1 for new_rank, old_rank in enumerate(unique_ranks)}  # Map old ranks to new continuous ranks
        
        # Apply mapping to adjust ranks
        adjusted_df.loc[feature] = df.loc[feature].map(rank_mapping)

    return adjusted_df

# Apply the function to adjust rankings
ranking_iqr_table = adjust_rankings(ranking_iqr_table)


# Print the ranking table
tools.display_dataframe_to_user(name="Adjusted Ranking of the IQR by IR for shapMeans", dataframe=ranking_iqr_table)
# Out:
# Adjusted Ranking of the IQR by IR for shapMeans
# <!--| quarto-html-table-processing: none -->
# <table id="itables_d67c9696_c7f6_45e5_8410_5606b7cfda50"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.4 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_d67c9696_c7f6_45e5_8410_5606b7cfda50:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>lr_shap_list_ir_1</th>\n      <th>lr_shap_list_ir_2</th>\n      <th>lr_shap_list_ir_3</th>\n      <th>lr_shap_list_ir_4</th>\n      <th>lr_shap_list_ir_5</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Aattr\", 1, 2, 3, 4, 5], [\"Battr\", 1, 3, 2, 4, 5], [\"Cattr\", 1, 2, 3, 4, 5], [\"Dattr\", 1, 2, 3, 4, 5], [\"Eattr\", 1, 2, 3, 4, 5], [\"Fattr\", 1, 2, 3, 4, 5], [\"A1attr\", 1, 2, 3, 4, 5], [\"B2attr\", 1, 2, 3, 4, 5], [\"C3attr\", 1, 2, 3, 4, 5], [\"D4attr\", 1, 2, 3, 4, 5], [\"E5attr\", 1, 2, 3, 4, 5], [\"F6attr\", 1, 2, 3, 4, 5], [\"A7attr\", 1, 2, 3, 4, 5], [\"B8attr\", 1, 2, 3, 4, 5], [\"C9attr\", 1, 2, 3, 4, 5], [\"D10attr\", 1, 2, 3, 4, 5], [\"E11attr\", 1, 2, 3, 4, 5], [\"F12attr\", 1, 2, 3, 4, 5], [\"A13attr\", 1, 2, 3, 4, 5], [\"B14attr\", 1, 2, 3, 4, 5], [\"C15attr\", 1, 2, 3, 4, 5], [\"D16attr\", 1, 2, 3, 4, 5], [\"E17attr\", 1, 2, 3, 4, 5], [\"F18attr\", 1, 2, 3, 4, 5], [\"A19attr\", 1, 2, 3, 4, 5], [\"B20attr\", 1, 2, 3, 4, 5], [\"C21attr\", 1, 2, 3, 4, 5], [\"D22attr\", 1, 2, 3, 5, 4], [\"E23attr\", 1, 2, 3, 4, 5], [\"F24attr\", 1, 2, 3, 4, 5], [\"A25attr\", 1, 2, 3, 4, 5], [\"B26attr\", 1, 2, 3, 4, 5], [\"C27attr\", 1, 2, 3, 4, 5], [\"D28attr\", 1, 2, 3, 5, 4], [\"E29attr\", 1, 2, 3, 4, 5], [\"F30attr\", 1, 2, 3, 4, 5]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ### Plots shapMeans

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure for heatmaps
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Heatmap for Mean-based Ranking
sns.heatmap(ranking_table, annot=True, cmap="coolwarm", linewidths=0.5, fmt=".0f", ax=axes[0])
axes[0].set_title("Ranking Based on Mean of shapMean", fontsize=14)
axes[0].set_xlabel("Imbalance Ratio (IR)", fontsize=12)
axes[0].set_ylabel("Feature", fontsize=12)

# Heatmap for Variance-based Ranking
sns.heatmap(ranking_std_table, annot=True, cmap="coolwarm", linewidths=0.5, fmt=".0f", ax=axes[1])
axes[1].set_title("Ranking Based on Variance of shapMean", fontsize=14)
axes[1].set_xlabel("Imbalance Ratio (IR)", fontsize=12)
axes[1].set_ylabel("")  # No label to avoid redundancy

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define the ranking tables (assuming they are already defined)
# ranking_table -> Mean-based rankings
# ranking_iqr_table -> Variance-based rankings

# Function to compute ranking proportions, accounting for ties
def compute_ranking_proportions(ranking_df):
    ranking_counts = ranking_df.apply(pd.Series.value_counts, axis=0).fillna(0)
    ranking_proportions = ranking_counts.div(ranking_counts.sum(axis=1), axis=0)
    
    return ranking_proportions

# Function to plot stacked bar chart
def plot_stacked_bar_chart(ranking_df, title):
    ranking_proportions = compute_ranking_proportions(ranking_df)

    fig, ax = plt.subplots(figsize=(10, 6))
    colors = sns.color_palette("Set1", len(ranking_df.columns))

    bottom_values = np.zeros(len(ranking_proportions.index))
    for i, ir in enumerate(ranking_df.columns):
        ax.bar(ranking_proportions.index, ranking_proportions[ir], label=ir, bottom=bottom_values, color=colors[i])
        bottom_values += ranking_proportions[ir]

    ax.set_xlabel("Ranking Position")
    ax.set_ylabel("Proportion")
    ax.set_title(title)
    ax.legend(title="Imbalance Ratio (IR)")
    ax.set_ylim(0, 1)

    plt.show()

# Function to plot pie charts for each ranking position (handling ties and removing 0%)
def plot_pie_charts(ranking_df, title):
    ranking_proportions = compute_ranking_proportions(ranking_df)

    fig, axes = plt.subplots(1, len(ranking_proportions.index), figsize=(15, 5))
    colors = sns.color_palette("Set2", len(ranking_df.columns))  # Define consistent colors for IRs

    all_labels = ranking_proportions.columns
    used_labels = set()  # Store IRs that appear in any pie for legend

    for i, rank in enumerate(ranking_proportions.index):
        ax = axes[i]
        proportions = ranking_proportions.loc[rank]

        # Remove IRs with 0% from labels and values
        valid_indices = proportions > 0
        filtered_proportions = proportions[valid_indices]
        filtered_labels = all_labels[valid_indices]

        # Store used IRs for the legend
        used_labels.update(filtered_labels)

        # Plot Pie Chart
        wedges, texts, autotexts = ax.pie(
            filtered_proportions,
            labels=[None] * len(filtered_labels),  # Remove labels inside pie
            autopct=lambda p: f'{p:.1f}%' if p > 0 else '',  # Only show % > 0
            colors=[colors[i] for i in range(len(filtered_labels))],
            startangle=90,
            wedgeprops={'edgecolor': 'black'}
        )

        ax.set_title(f"Ranking {rank}")

    # Create a single legend
    fig.legend(
        handles=[plt.Rectangle((0, 0), 1, 1, color=colors[i]) for i, lbl in enumerate(all_labels) if lbl in used_labels],
        labels=[lbl for lbl in all_labels if lbl in used_labels],
        title="Imbalance Ratio (IR)",
        loc="upper right"
    )

    fig.suptitle(title, fontsize=14)
    plt.show()

# Generate Stacked Bar Chart for Mean-Based Rankings (handling ties)
plot_stacked_bar_chart(ranking_table, "Proportion of IRs at Each Ranking (Mean-Based, Ties Considered)")

# Generate Stacked Bar Chart for Variance-Based Rankings (handling ties)
plot_stacked_bar_chart(ranking_iqr_table, "Proportion of IRs at Each Ranking (Variance-Based, Ties Considered)")

# Generate Pie Charts for Mean-Based Rankings (handling ties)
plot_pie_charts(ranking_table, "Distribution of IRs per Ranking (Mean-Based, Ties Considered)")

# Generate Pie Charts for Variance-Based Rankings (handling ties)
plot_pie_charts(ranking_iqr_table, "Distribution of IRs per Ranking (Variance-Based, Ties Considered)")

# %% [markdown]
# ***
# ***
# ***
# ## std SHAP
#
# - Variability of std for Shap (level I Shap, for subsets)
# - Not only standard deviation increasing with increasing Imbalance Ration, but also Shap std is more changing for highier imbalance. It meas that there is more outlier results for highier IR

# %%
# Group by 'imbalanceRatio' and compute statistics for 'shapMean'
stdStatistics = (
    sorted_orderValuesScore.groupby(["imbalance_ratio", 'feature'])
    .agg(
        median=("shapStd", "median"),
        mean=("shapStd", "mean"),
        std=("shapStd", "std"),
        iqr=("shapStd", lambda x: x.quantile(0.75) - x.quantile(0.25)),
    )
)
stdStatistics.reset_index(inplace=True)

# %%
stdStatistics
# Out:
#        imbalance_ratio  feature    median      mean       std       iqr
# 0    lr_shap_list_ir_1  A13attr  0.341603  0.444569  0.348793  0.368698
# 1    lr_shap_list_ir_1  A19attr  0.420192  0.520158  0.419926  0.537949
# 2    lr_shap_list_ir_1   A1attr  0.445467  0.506373  0.428920  0.610556
# 3    lr_shap_list_ir_1  A25attr  0.402719  0.448403  0.353981  0.433567
# 4    lr_shap_list_ir_1   A7attr  0.528300  0.639987  0.467947  0.705840
# ..                 ...      ...       ...       ...       ...       ...
# 175  lr_shap_list_ir_5  F18attr  0.688256  0.682887  0.167566  0.250733
# 176  lr_shap_list_ir_5  F24attr  0.143439  0.155127  0.103298  0.147115
# 177  lr_shap_list_ir_5  F30attr  0.270375  0.269784  0.129240  0.195661
# 178  lr_shap_list_ir_5   F6attr  0.195067  0.216342  0.120822  0.157689
# 179  lr_shap_list_ir_5    Fattr  0.242101  0.240418  0.139036  0.202065
#
# [180 rows x 6 columns]

# %%
# Reset index to prepare for plotting
df_reset = stdStatistics

# Plotting the dotted chart
plt.figure(figsize=(12, 6))
for ir in df_reset["imbalance_ratio"].unique():
    subset = df_reset[df_reset["imbalance_ratio"] == ir]
#     plt.scatter(subset["feature"], subset["median"], label=f"{ir} (median)", alpha=0.7)  # median chart
    plt.scatter(subset["feature"], subset["mean"], label=f"{ir} (mean)", alpha=0.7)  # mean chart
#     plt.scatter(subset["feature"], subset["std"], label=f"{ir} (std)", alpha=0.7)  # std chart
#     plt.scatter(subset["feature"], subset["iqr"], label=f"{ir} (iqr)", alpha=0.7)  # iqr chart

plt.xticks(rotation=90)
plt.title("Dotted Chart for mean by Imbalance Ratio")
plt.ylabel("Values")
plt.xlabel("Features")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import scipy.stats as stats
import itertools

# Load your dataset
sorted_orderValuesScore = pd.read_csv("sorted_orderValuesScore_lr.csv")
sorted_orderValuesScore.drop("Unnamed: 0", axis=1, inplace=True)
sorted_orderValuesScore.columns = ['feature', 'shapMean', 'shapStd', 'shapSum', 'subset', 'imbalance_ratio']

# Get unique IRs and features
imbalance_ratios = sorted_orderValuesScore['imbalance_ratio'].unique()
features = sorted_orderValuesScore['feature'].unique()

# Dictionary to store rankings
rankings_dict = {feature: {} for feature in features}

for feature in features:
    # Filter data for the feature
    feature_data = sorted_orderValuesScore[sorted_orderValuesScore['feature'] == feature]

    # Compute mean shapMean per IR
    means = feature_data.groupby('imbalance_ratio')['shapStd'].mean().sort_values(ascending=False)
    
    # Initialize significance matrix
    significance_matrix = pd.DataFrame(1.0, index=imbalance_ratios, columns=imbalance_ratios)

    # Pairwise t-tests
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        group1 = feature_data[feature_data['imbalance_ratio'] == ir1]['shapMean']
        group2 = feature_data[feature_data['imbalance_ratio'] == ir2]['shapMean']
        
        if len(group1) > 1 and len(group2) > 1:  # Ensure enough data
            stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)  # Welch’s t-test
        else:
            p_value = 1  # Assume no difference if insufficient data
        
        # Store p-value
        significance_matrix.loc[ir1, ir2] = p_value
        significance_matrix.loc[ir2, ir1] = p_value

    # Assign initial rankings based on means
    ranking_values = {ir: rank + 1 for rank, ir in enumerate(means.index)}

    # Adjust rankings if no significant differences
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        if significance_matrix.loc[ir1, ir2] >= 0.05:  # No significant difference
            min_rank = min(ranking_values[ir1], ranking_values[ir2])
            ranking_values[ir1] = ranking_values[ir2] = min_rank

    rankings_dict[feature] = ranking_values

# Convert to DataFrame
ranking_table = pd.DataFrame(rankings_dict).T.fillna(0)

sorted_columns = sorted(ranking_table.columns, key=lambda x: int(x.split('_')[-1]))

# Reorder the DataFrame
ranking_table = ranking_table[sorted_columns]

# Function to adjust rankings so that ties do not skip numbers
def adjust_rankings(df):
    adjusted_df = df.copy()
    
    for feature in df.index:
        unique_ranks = sorted(set(df.loc[feature]))  # Get unique ranks in sorted order
        rank_mapping = {old_rank: new_rank + 1 for new_rank, old_rank in enumerate(unique_ranks)}  # Map old ranks to new continuous ranks
        
        # Apply mapping to adjust ranks
        adjusted_df.loc[feature] = df.loc[feature].map(rank_mapping)

    return adjusted_df

# Apply the function to adjust rankings
ranking_table = adjust_rankings(ranking_table)

# Display the updated ranking table
tools.display_dataframe_to_user(name="Adjusted Ranking of the mean by IR for shapStd", dataframe=ranking_table)
# Out:
# Adjusted Ranking of the mean by IR for shapStd
# <!--| quarto-html-table-processing: none -->
# <table id="itables_f38ac4aa_5cdb_4ab4_9bc7_5cdb99bb2baa"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.4 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_f38ac4aa_5cdb_4ab4_9bc7_5cdb99bb2baa:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>lr_shap_list_ir_1</th>\n      <th>lr_shap_list_ir_2</th>\n      <th>lr_shap_list_ir_3</th>\n      <th>lr_shap_list_ir_4</th>\n      <th>lr_shap_list_ir_5</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Aattr\", 1, 2, 3, 3, 4], [\"Battr\", 1, 2, 3, 3, 4], [\"Cattr\", 1, 2, 3, 4, 5], [\"Dattr\", 1, 2, 3, 3, 3], [\"Eattr\", 1, 2, 3, 4, 4], [\"Fattr\", 1, 2, 3, 3, 4], [\"A1attr\", 1, 2, 3, 4, 5], [\"B2attr\", 1, 2, 3, 3, 3], [\"C3attr\", 1, 2, 3, 4, 5], [\"D4attr\", 1, 2, 2, 2, 3], [\"E5attr\", 1, 2, 3, 3, 4], [\"F6attr\", 1, 2, 3, 3, 4], [\"A7attr\", 1, 2, 3, 3, 4], [\"B8attr\", 1, 2, 3, 4, 5], [\"C9attr\", 1, 2, 3, 4, 5], [\"D10attr\", 1, 2, 3, 4, 4], [\"E11attr\", 1, 2, 2, 2, 3], [\"F12attr\", 1, 2, 2, 2, 3], [\"A13attr\", 1, 2, 3, 3, 4], [\"B14attr\", 1, 2, 2, 2, 2], [\"C15attr\", 1, 2, 3, 3, 3], [\"D16attr\", 1, 2, 3, 3, 4], [\"E17attr\", 1, 2, 3, 4, 5], [\"F18attr\", 1, 2, 2, 2, 3], [\"A19attr\", 1, 2, 2, 2, 2], [\"B20attr\", 1, 2, 3, 3, 4], [\"C21attr\", 1, 2, 3, 4, 4], [\"D22attr\", 1, 2, 3, 4, 4], [\"E23attr\", 1, 2, 3, 4, 5], [\"F24attr\", 1, 2, 3, 4, 5], [\"A25attr\", 1, 2, 3, 4, 4], [\"B26attr\", 1, 2, 3, 4, 5], [\"C27attr\", 1, 2, 3, 3, 4], [\"D28attr\", 1, 2, 2, 2, 3], [\"E29attr\", 1, 2, 3, 3, 4], [\"F30attr\", 1, 2, 3, 3, 3]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
# Reset index to prepare for plotting
df_reset = stdStatistics

# Plotting the dotted chart
plt.figure(figsize=(12, 6))
for ir in df_reset["imbalance_ratio"].unique():
    subset = df_reset[df_reset["imbalance_ratio"] == ir]
#     plt.scatter(subset["feature"], subset["median"], label=f"{ir} (median)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["mean"], label=f"{ir} (mean)", alpha=0.7)
    plt.scatter(subset["feature"], subset["std"], label=f"{ir} (std)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["iqr"], label=f"{ir} (iqr)", alpha=0.7)

plt.xticks(rotation=90)
plt.title("Dotted Chart for STD by Imbalance Ratio")
plt.ylabel("Values")
plt.xlabel("Features")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import scipy.stats as stats
import itertools

# Load the dataset
sorted_orderValuesScore = pd.read_csv("sorted_orderValuesScore_lr.csv")
sorted_orderValuesScore.drop("Unnamed: 0", axis=1, inplace=True)
sorted_orderValuesScore.columns = ['feature', 'shapMean', 'shapStd', 'shapSum', 'subset', 'imbalance_ratio']

# Get unique features and imbalance ratios
features = sorted_orderValuesScore['feature'].unique()
imbalance_ratios = sorted_orderValuesScore['imbalance_ratio'].unique()

# Dictionary to store rankings based on standard deviation of shapMean
rankings_std_dict = {feature: {} for feature in features}

for feature in features:
    # Filter data for the feature
    feature_data = sorted_orderValuesScore[sorted_orderValuesScore['feature'] == feature]

    # Compute std deviation of shapMean per IR
    std_devs = feature_data.groupby('imbalance_ratio')['shapStd'].std().sort_values(ascending=False)
    
    # Initialize significance matrix
    significance_matrix = pd.DataFrame(1.0, index=imbalance_ratios, columns=imbalance_ratios)

    # Pairwise Levene's test for variance comparison
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        group1 = feature_data[feature_data['imbalance_ratio'] == ir1]['shapMean']
        group2 = feature_data[feature_data['imbalance_ratio'] == ir2]['shapMean']
        
        if len(group1) > 1 and len(group2) > 1:  # Ensure enough data
            stat, p_value = stats.levene(group1, group2, center='median')  # Levene’s test
        else:
            p_value = 1  # Assume no difference if insufficient data
        
        # Store p-value
        significance_matrix.loc[ir1, ir2] = p_value
        significance_matrix.loc[ir2, ir1] = p_value

    # Assign initial rankings based on standard deviations
    ranking_values = {ir: rank + 1 for rank, ir in enumerate(std_devs.index)}

    # Adjust rankings if no significant differences
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        if significance_matrix.loc[ir1, ir2] >= 0.05:  # No significant difference
            min_rank = min(ranking_values[ir1], ranking_values[ir2])
            ranking_values[ir1] = ranking_values[ir2] = min_rank

    rankings_std_dict[feature] = ranking_values

# Convert to DataFrame
ranking_std_table = pd.DataFrame(rankings_std_dict).T.fillna(0)

# Reorder the columns based on IR numeric values
sorted_columns = sorted(ranking_std_table.columns, key=lambda x: int(x.split('_')[-1]))
ranking_std_table = ranking_std_table[sorted_columns]

# Function to adjust rankings so that ties do not skip numbers
def adjust_rankings(df):
    adjusted_df = df.copy()
    
    for feature in df.index:
        unique_ranks = sorted(set(df.loc[feature]))  # Get unique ranks in sorted order
        rank_mapping = {old_rank: new_rank + 1 for new_rank, old_rank in enumerate(unique_ranks)}  # Map old ranks to new continuous ranks
        
        # Apply mapping to adjust ranks
        adjusted_df.loc[feature] = df.loc[feature].map(rank_mapping)

    return adjusted_df

# Apply the function to adjust rankings
ranking_std_table = adjust_rankings(ranking_std_table)

# Display the updated ranking table
tools.display_dataframe_to_user(name="Adjusted Ranking of the variance by IR for shapStd", dataframe=ranking_std_table)
# Out:
# Adjusted Ranking of the variance by IR for shapStd
# <!--| quarto-html-table-processing: none -->
# <table id="itables_c3c69b31_3919_4dbd_a305_9c99ba4e4688"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.4 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_c3c69b31_3919_4dbd_a305_9c99ba4e4688:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>lr_shap_list_ir_1</th>\n      <th>lr_shap_list_ir_2</th>\n      <th>lr_shap_list_ir_3</th>\n      <th>lr_shap_list_ir_4</th>\n      <th>lr_shap_list_ir_5</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Aattr\", 1, 2, 3, 3, 4], [\"Battr\", 1, 2, 2, 3, 4], [\"Cattr\", 1, 2, 3, 3, 4], [\"Dattr\", 1, 2, 3, 4, 5], [\"Eattr\", 1, 2, 3, 4, 4], [\"Fattr\", 1, 2, 3, 3, 4], [\"A1attr\", 1, 2, 3, 4, 4], [\"B2attr\", 1, 2, 3, 4, 5], [\"C3attr\", 1, 2, 3, 4, 5], [\"D4attr\", 1, 2, 3, 4, 5], [\"E5attr\", 1, 2, 3, 4, 5], [\"F6attr\", 1, 2, 3, 4, 4], [\"A7attr\", 1, 2, 3, 4, 4], [\"B8attr\", 1, 2, 3, 4, 5], [\"C9attr\", 1, 2, 3, 4, 5], [\"D10attr\", 1, 2, 3, 4, 4], [\"E11attr\", 1, 2, 3, 4, 5], [\"F12attr\", 1, 2, 3, 3, 4], [\"A13attr\", 1, 2, 3, 3, 4], [\"B14attr\", 1, 2, 3, 4, 5], [\"C15attr\", 1, 2, 3, 4, 5], [\"D16attr\", 1, 2, 3, 3, 4], [\"E17attr\", 1, 2, 3, 4, 4], [\"F18attr\", 1, 2, 3, 4, 5], [\"A19attr\", 1, 2, 2, 3, 4], [\"B20attr\", 1, 2, 3, 4, 5], [\"C21attr\", 1, 2, 3, 4, 5], [\"D22attr\", 1, 2, 3, 4, 4], [\"E23attr\", 1, 2, 3, 4, 4], [\"F24attr\", 1, 2, 3, 4, 5], [\"A25attr\", 1, 2, 3, 3, 4], [\"B26attr\", 1, 2, 3, 3, 4], [\"C27attr\", 1, 2, 3, 3, 4], [\"D28attr\", 1, 2, 3, 4, 4], [\"E29attr\", 1, 2, 3, 3, 4], [\"F30attr\", 1, 2, 2, 3, 4]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
# Reset index to prepare for plotting
df_reset = stdStatistics

# Plotting the dotted chart
plt.figure(figsize=(12, 6))
for ir in df_reset["imbalance_ratio"].unique():
    subset = df_reset[df_reset["imbalance_ratio"] == ir]
#     plt.scatter(subset["feature"], subset["median"], label=f"{ir} (median)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["mean"], label=f"{ir} (mean)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["std"], label=f"{ir} (std)", alpha=0.7)
    plt.scatter(subset["feature"], subset["iqr"], label=f"{ir} (iqr)", alpha=0.7)

plt.xticks(rotation=90)
plt.title("Dotted Chart for IQR by Imbalance Ratio")
plt.ylabel("Values")
plt.xlabel("Features")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# ***
# ***
# ***
# ## SHAP stats by ID

# %%
import os
import pandas as pd
import numpy as np
from glob import glob

# Definir la ruta donde se encuentran los archivos SHAP
shap_path = "/home/guillen/Conference Paper SHAP Maciej actualizado/Satimage/shap/"

# Iterar sobre cada IR (1 a 5)
for j in range(1, 6):
    # Lista para almacenar los DataFrames procesados para este IR
    df_list = []

    # Iterar sobre cada subset (1 a 160)
    for i in range(1, 149):
        # Cargar los archivos SHAP para cada clase
        shap_file_0 = os.path.join(shap_path, f"lr_shap_list_ir_{j}_subset_{i}_class0.parquet")
        shap_file_1 = os.path.join(shap_path, f"lr_shap_list_ir_{j}_subset_{i}_class1.parquet")

        if os.path.exists(shap_file_0) and os.path.exists(shap_file_1):
            df_0 = pd.read_parquet(shap_file_0)
            df_1 = pd.read_parquet(shap_file_1)

            # Seleccionar filas de df_0 cuando la clase real es 'NO'
            df_0_filtered = df_0[df_0['Real_class'] == 'NO']

            # Seleccionar filas de df_1 cuando la clase real es 'SI'
            df_1_filtered = df_1[df_1['Real_class'] == 'SI']

            # Concatenar ambos DataFrames
            df_selected = pd.concat([df_0_filtered, df_1_filtered], ignore_index=True)

            # Tomar valores absolutos de los SHAP values
            feature_cols = [col for col in df_selected.columns if col not in ['PATIENT_ID', 'Real_class', 'Predicted_class', 'Model_Output']]
            df_selected[feature_cols] = df_selected[feature_cols].abs()

            df_list.append(df_selected)
        else:
            print(f"Skipping missing files for IR {j}, subset {i}")

    # Verificar que se han cargado datos antes de concatenar
    if df_list:
        # Concatenar todos los datasets de este IR
        df_all = pd.concat(df_list, ignore_index=True)

        # Agrupar por `PATIENT_ID` y calcular la media de los valores absolutos de SHAP
        df_grouped = df_all.groupby(['PATIENT_ID', 'Real_class'])[feature_cols].mean().reset_index()

        # Guardar el resultado en un nuevo archivo
        output_filename = os.path.join(shap_path, f"lr_shap_aggregated_ir_{j}.parquet")
        df_grouped.to_parquet(output_filename, index=False)

        print(f"Processed IR {j}: Saved to {output_filename}")
    else:
        print(f"No data found for IR {j}, skipping.")

print("Processing completed! SHAP values have been aggregated and saved.")
# Out:
# Skipping missing files for IR 1, subset 103
# Skipping missing files for IR 1, subset 104
# Skipping missing files for IR 1, subset 105
# Skipping missing files for IR 1, subset 106
# Skipping missing files for IR 1, subset 107
# Skipping missing files for IR 1, subset 108
# Skipping missing files for IR 1, subset 109
# Skipping missing files for IR 1, subset 110
# Skipping missing files for IR 1, subset 111
# Skipping missing files for IR 1, subset 112
# Skipping missing files for IR 1, subset 113
# Skipping missing files for IR 1, subset 114
# Skipping missing files for IR 1, subset 115
# Skipping missing files for IR 1, subset 116
# Skipping missing files for IR 1, subset 117
# Skipping missing files for IR 1, subset 118
# Skipping missing files for IR 1, subset 119
# Skipping missing files for IR 1, subset 120
# Skipping missing files for IR 1, subset 121
# Skipping missing files for IR 1, subset 122
# Skipping missing files for IR 1, subset 123
# Skipping missing files for IR 1, subset 124
# Skipping missing files for IR 1, subset 125
# Skipping missing files for IR 1, subset 126
# Skipping missing files for IR 1, subset 127
# Skipping missing files for IR 1, subset 128
# Skipping missing files for IR 1, subset 129
# Skipping missing files for IR 1, subset 130
# Skipping missing files for IR 1, subset 131
# Skipping missing files for IR 1, subset 132
# Skipping missing files for IR 1, subset 133
# Skipping missing files for IR 1, subset 134
# Skipping missing files for IR 1, subset 135
# Skipping missing files for IR 1, subset 136
# Skipping missing files for IR 1, subset 137
# Skipping missing files for IR 1, subset 138
# Skipping missing files for IR 1, subset 139
# Skipping missing files for IR 1, subset 140
# Skipping missing files for IR 1, subset 141
# Skipping missing files for IR 1, subset 142
# Skipping missing files for IR 1, subset 143
# Skipping missing files for IR 1, subset 144
# Skipping missing files for IR 1, subset 145
# Skipping missing files for IR 1, subset 146
# Skipping missing files for IR 1, subset 147
# Skipping missing files for IR 1, subset 148
# Processed IR 1: Saved to /home/guillen/Conference Paper SHAP Maciej actualizado/Satimage/shap/lr_shap_aggregated_ir_1.parquet
# Skipping missing files for IR 2, subset 103
# Skipping missing files for IR 2, subset 104
# Skipping missing files for IR 2, subset 105
# Skipping missing files for IR 2, subset 106
# Skipping missing files for IR 2, subset 107
# Skipping missing files for IR 2, subset 108
# Skipping missing files for IR 2, subset 109
# Skipping missing files for IR 2, subset 110
# Skipping missing files for IR 2, subset 111
# Skipping missing files for IR 2, subset 112
# Skipping missing files for IR 2, subset 113
# Skipping missing files for IR 2, subset 114
# Skipping missing files for IR 2, subset 115
# Skipping missing files for IR 2, subset 116
# Skipping missing files for IR 2, subset 117
# Skipping missing files for IR 2, subset 118
# Skipping missing files for IR 2, subset 119
# Skipping missing files for IR 2, subset 120
# Skipping missing files for IR 2, subset 121
# Skipping missing files for IR 2, subset 122
# Skipping missing files for IR 2, subset 123
# Skipping missing files for IR 2, subset 124
# Skipping missing files for IR 2, subset 125
# Skipping missing files for IR 2, subset 126
# Skipping missing files for IR 2, subset 127
# Skipping missing files for IR 2, subset 128
# Skipping missing files for IR 2, subset 129
# Skipping missing files for IR 2, subset 130
# Skipping missing files for IR 2, subset 131
# Skipping missing files for IR 2, subset 132
# Skipping missing files for IR 2, subset 133
# Skipping missing files for IR 2, subset 134
# Skipping missing files for IR 2, subset 135
# Skipping missing files for IR 2, subset 136
# Skipping missing files for IR 2, subset 137
# Skipping missing files for IR 2, subset 138
# Skipping missing files for IR 2, subset 139
# Skipping missing files for IR 2, subset 140
# Skipping missing files for IR 2, subset 141
# Skipping missing files for IR 2, subset 142
# Skipping missing files for IR 2, subset 143
# Skipping missing files for IR 2, subset 144
# Skipping missing files for IR 2, subset 145
# Skipping missing files for IR 2, subset 146
# Skipping missing files for IR 2, subset 147
# Skipping missing files for IR 2, subset 148
# Processed IR 2: Saved to /home/guillen/Conference Paper SHAP Maciej actualizado/Satimage/shap/lr_shap_aggregated_ir_2.parquet
# Skipping missing files for IR 3, subset 103
# Skipping missing files for IR 3, subset 104
# Skipping missing files for IR 3, subset 105
# Skipping missing files for IR 3, subset 106
# Skipping missing files for IR 3, subset 107
# Skipping missing files for IR 3, subset 108
# Skipping missing files for IR 3, subset 109
# Skipping missing files for IR 3, subset 110
# Skipping missing files for IR 3, subset 111
# Skipping missing files for IR 3, subset 112
# Skipping missing files for IR 3, subset 113
# Skipping missing files for IR 3, subset 114
# Skipping missing files for IR 3, subset 115
# Skipping missing files for IR 3, subset 116
# Skipping missing files for IR 3, subset 117
# Skipping missing files for IR 3, subset 118
# Skipping missing files for IR 3, subset 119
# Skipping missing files for IR 3, subset 120
# Skipping missing files for IR 3, subset 121
# Skipping missing files for IR 3, subset 122
# Skipping missing files for IR 3, subset 123
# Skipping missing files for IR 3, subset 124
# Skipping missing files for IR 3, subset 125
# Skipping missing files for IR 3, subset 126
# Skipping missing files for IR 3, subset 127
# Skipping missing files for IR 3, subset 128
# Skipping missing files for IR 3, subset 129
# Skipping missing files for IR 3, subset 130
# Skipping missing files for IR 3, subset 131
# Skipping missing files for IR 3, subset 132
# Skipping missing files for IR 3, subset 133
# Skipping missing files for IR 3, subset 134
# Skipping missing files for IR 3, subset 135
# Skipping missing files for IR 3, subset 136
# Skipping missing files for IR 3, subset 137
# Skipping missing files for IR 3, subset 138
# Skipping missing files for IR 3, subset 139
# Skipping missing files for IR 3, subset 140
# Skipping missing files for IR 3, subset 141
# Skipping missing files for IR 3, subset 142
# Skipping missing files for IR 3, subset 143
# Skipping missing files for IR 3, subset 144
# Skipping missing files for IR 3, subset 145
# Skipping missing files for IR 3, subset 146
# Skipping missing files for IR 3, subset 147
# Skipping missing files for IR 3, subset 148
# Processed IR 3: Saved to /home/guillen/Conference Paper SHAP Maciej actualizado/Satimage/shap/lr_shap_aggregated_ir_3.parquet
# Skipping missing files for IR 4, subset 103
# Skipping missing files for IR 4, subset 104
# Skipping missing files for IR 4, subset 105
# Skipping missing files for IR 4, subset 106
# Skipping missing files for IR 4, subset 107
# Skipping missing files for IR 4, subset 108
# Skipping missing files for IR 4, subset 109
# Skipping missing files for IR 4, subset 110
# Skipping missing files for IR 4, subset 111
# Skipping missing files for IR 4, subset 112
# Skipping missing files for IR 4, subset 113
# Skipping missing files for IR 4, subset 114
# Skipping missing files for IR 4, subset 115
# Skipping missing files for IR 4, subset 116
# Skipping missing files for IR 4, subset 117
# Skipping missing files for IR 4, subset 118
# Skipping missing files for IR 4, subset 119
# Skipping missing files for IR 4, subset 120
# Skipping missing files for IR 4, subset 121
# Skipping missing files for IR 4, subset 122
# Skipping missing files for IR 4, subset 123
# Skipping missing files for IR 4, subset 124
# Skipping missing files for IR 4, subset 125
# Skipping missing files for IR 4, subset 126
# Skipping missing files for IR 4, subset 127
# Skipping missing files for IR 4, subset 128
# Skipping missing files for IR 4, subset 129
# Skipping missing files for IR 4, subset 130
# Skipping missing files for IR 4, subset 131
# Skipping missing files for IR 4, subset 132
# Skipping missing files for IR 4, subset 133
# Skipping missing files for IR 4, subset 134
# Skipping missing files for IR 4, subset 135
# Skipping missing files for IR 4, subset 136
# Skipping missing files for IR 4, subset 137
# Skipping missing files for IR 4, subset 138
# Skipping missing files for IR 4, subset 139
# Skipping missing files for IR 4, subset 140
# Skipping missing files for IR 4, subset 141
# Skipping missing files for IR 4, subset 142
# Skipping missing files for IR 4, subset 143
# Skipping missing files for IR 4, subset 144
# Skipping missing files for IR 4, subset 145
# Skipping missing files for IR 4, subset 146
# Skipping missing files for IR 4, subset 147
# Skipping missing files for IR 4, subset 148
# Processed IR 4: Saved to /home/guillen/Conference Paper SHAP Maciej actualizado/Satimage/shap/lr_shap_aggregated_ir_4.parquet
# Skipping missing files for IR 5, subset 103
# Skipping missing files for IR 5, subset 104
# Skipping missing files for IR 5, subset 105
# Skipping missing files for IR 5, subset 106
# Skipping missing files for IR 5, subset 107
# Skipping missing files for IR 5, subset 108
# Skipping missing files for IR 5, subset 109
# Skipping missing files for IR 5, subset 110
# Skipping missing files for IR 5, subset 111
# Skipping missing files for IR 5, subset 112
# Skipping missing files for IR 5, subset 113
# Skipping missing files for IR 5, subset 114
# Skipping missing files for IR 5, subset 115
# Skipping missing files for IR 5, subset 116
# Skipping missing files for IR 5, subset 117
# Skipping missing files for IR 5, subset 118
# Skipping missing files for IR 5, subset 119
# Skipping missing files for IR 5, subset 120
# Skipping missing files for IR 5, subset 121
# Skipping missing files for IR 5, subset 122
# Skipping missing files for IR 5, subset 123
# Skipping missing files for IR 5, subset 124
# Skipping missing files for IR 5, subset 125
# Skipping missing files for IR 5, subset 126
# Skipping missing files for IR 5, subset 127
# Skipping missing files for IR 5, subset 128
# Skipping missing files for IR 5, subset 129
# Skipping missing files for IR 5, subset 130
# Skipping missing files for IR 5, subset 131
# Skipping missing files for IR 5, subset 132
# Skipping missing files for IR 5, subset 133
# Skipping missing files for IR 5, subset 134
# Skipping missing files for IR 5, subset 135
# Skipping missing files for IR 5, subset 136
# Skipping missing files for IR 5, subset 137
# Skipping missing files for IR 5, subset 138
# Skipping missing files for IR 5, subset 139
# Skipping missing files for IR 5, subset 140
# Skipping missing files for IR 5, subset 141
# Skipping missing files for IR 5, subset 142
# Skipping missing files for IR 5, subset 143
# Skipping missing files for IR 5, subset 144
# Skipping missing files for IR 5, subset 145
# Skipping missing files for IR 5, subset 146
# Skipping missing files for IR 5, subset 147
# Skipping missing files for IR 5, subset 148
# Processed IR 5: Saved to /home/guillen/Conference Paper SHAP Maciej actualizado/Satimage/shap/lr_shap_aggregated_ir_5.parquet
# Processing completed! SHAP values have been aggregated and saved.

# %%
import os
import numpy as np
import pandas as pd
from scipy.stats import iqr
shap_aggregated = {}
for j in range(1, 6):
    shap_path = "/home/guillen/Conference Paper SHAP Maciej actualizado/Satimage/shap/"
    file_path = os.path.join(shap_path, f"lr_shap_aggregated_ir_{j}.parquet")
    shap_aggregated[j] = pd.read_parquet(file_path)

shap_aggregated[1]
# Out:
#       PATIENT_ID Real_class     Aattr     Battr     Cattr     Dattr     Eattr  \
# 0              1         NO  0.156958  1.775508  1.049601  0.805260  0.111781
# 1              2         NO  0.939969  1.597196  0.129822  0.458795  0.859774
# 2              3         NO  0.638448  0.232264  0.071712  0.344930  0.741934
# 3              4         NO  0.937868  0.830575  0.337695  0.091026  0.810517
# 4              5         NO  0.648590  1.492558  0.170866  0.195928  0.796937
# ...          ...        ...       ...       ...       ...       ...       ...
# 6425        6426         NO  1.240876  1.373826  0.854913  0.543293  1.333045
# 6426        6427         SI  0.077975  0.417233  0.395175  0.622909  0.229384
# 6427        6428         SI  1.391294  0.616033  0.664923  0.387870  2.043310
# 6428        6429         SI  0.110509  0.226831  0.724574  1.204652  0.244217
# 6429        6430         NO  1.318998  2.061924  1.064319  0.855837  1.251062
#
#          Fattr    A1attr    B2attr  ...   C21attr   D22attr   E23attr  \
# 0     1.812862  1.108468  0.984536  ...  1.056951  0.969181  0.070008
# 1     0.624215  0.744575  0.745862  ...  0.536517  0.313341  0.602731
# 2     0.293130  0.086770  0.644467  ...  0.823257  1.153103  0.576239
# 3     0.810574  0.280481  0.089873  ...  0.350339  0.255939  1.314841
# 4     1.760872  0.160140  0.157470  ...  0.692095  0.276462  0.586417
# ...        ...       ...       ...  ...       ...       ...       ...
# 6425  1.284527  0.614595  0.314807  ...  0.592744  0.546595  0.654993
# 6426  0.247405  0.330902  0.129933  ...  0.248929  0.161807  0.346421
# 6427  1.299497  0.440373  0.076026  ...  0.150605  0.313112  0.380107
# 6428  0.340129  0.784170  0.601338  ...  0.142485  0.061678  0.058564
# 6429  2.360630  1.500284  0.756817  ...  0.574362  0.517304  1.237387
#
#        F24attr   A25attr   B26attr   C27attr   D28attr   E29attr   F30attr
# 0     1.571688  1.008615  0.785554  0.053884  1.841158  1.062311  0.528914
# 1     1.304954  0.777693  0.521896  0.479924  0.322792  0.607634  0.274930
# 2     0.107679  0.408928  0.869905  0.551593  0.608984  0.157757  0.261847
# 3     1.449148  0.477202  0.319072  1.021471  1.557993  0.660577  0.126019
# 4     1.714588  0.734549  0.421690  0.590156  1.662962  0.670218  0.667796
# ...        ...       ...       ...       ...       ...       ...       ...
# 6425  2.228350  0.765860  0.961698  0.527534  1.770878  1.030287  0.736597
# 6426  0.228994  0.231467  0.093557  0.143572  0.758516  0.264801  0.072614
# 6427  1.063811  0.208006  1.010641  0.358801  0.153191  0.109171  0.823194
# 6428  0.039479  0.268406  0.507923  0.208205  0.153227  0.508849  0.610969
# 6429  1.737657  1.212136  0.540451  1.305357  1.729520  0.632487  0.431392
#
# [6430 rows x 38 columns]

# %%
feature_cols = [col for col in shap_aggregated[1].columns if col not in ['PATIENT_ID', 'Real_class']]

metrics = []
for feature in feature_cols:
    for j in range(1, 6):
        data = shap_aggregated[j][feature]
        metrics.append({
            'feature': feature,
            'IR': j,
            'mean': np.mean(data),
            'median': np.median(data),# Additional metric for ranking
            'std': np.std(data),
            'iqr': iqr(data)
        })

metrics_df = pd.DataFrame(metrics)

# Generate rankings (higher value = rank 1)
ranking_df = metrics_df.copy()
for metric in ['mean', 'std', 'iqr', 'median']:
    ranking_df[metric + '_Rank'] = ranking_df.groupby('feature')[metric].rank(method='dense', ascending=False)

# Display ranking table
import ace_tools_open as tools
tools.display_dataframe_to_user(name="Ranking Metrics by IR", dataframe=ranking_df)
# Out:
# Ranking Metrics by IR
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4458beec_af5f_4bab_afe0_c071bc91be56"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.4 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4458beec_af5f_4bab_afe0_c071bc91be56:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>feature</th>\n      <th>IR</th>\n      <th>mean</th>\n      <th>median</th>\n      <th>std</th>\n      <th>iqr</th>\n      <th>mean_Rank</th>\n      <th>std_Rank</th>\n      <th>iqr_Rank</th>\n      <th>median_Rank</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Aattr\", 1, 0.675201, 0.587763, 0.490795, 0.824864, 1.0, 1.0, 1.0, 1.0], [\"Aattr\", 2, 0.350682, 0.308675, 0.251195, 0.414155, 2.0, 2.0, 2.0, 2.0], [\"Aattr\", 3, 0.205525, 0.180818, 0.14597, 0.242349, 3.0, 3.0, 3.0, 3.0], [\"Aattr\", 4, 0.17788, 0.155806, 0.125515, 0.208071, 4.0, 4.0, 4.0, 4.0], [\"Aattr\", 5, 0.128123, 0.11154, 0.090265, 0.148606, 5.0, 5.0, 5.0, 5.0], [\"Battr\", 1, 1.041703, 0.900274, 0.749781, 1.040341, 1.0, 1.0, 1.0, 1.0], [\"Battr\", 2, 0.430286, 0.374489, 0.310662, 0.430591, 2.0, 2.0, 2.0, 2.0], [\"Battr\", 3, 0.334415, 0.285464, 0.242859, 0.320828, 3.0, 3.0, 3.0, 3.0], [\"Battr\", 4, 0.280217, 0.240544, 0.203088, 0.274696, 4.0, 4.0, 4.0, 4.0], [\"Battr\", 5, 0.216331, 0.183473, 0.157629, 0.208493, 5.0, 5.0, 5.0, 5.0], [\"Cattr\", 1, 0.787337, 0.746828, 0.494417, 0.76986, 1.0, 1.0, 1.0, 1.0], [\"Cattr\", 2, 0.347008, 0.329765, 0.214949, 0.340908, 2.0, 2.0, 2.0, 2.0], [\"Cattr\", 3, 0.232047, 0.219185, 0.145055, 0.225143, 3.0, 3.0, 3.0, 3.0], [\"Cattr\", 4, 0.170562, 0.162588, 0.105992, 0.164465, 4.0, 4.0, 4.0, 4.0], [\"Cattr\", 5, 0.125451, 0.11984, 0.077727, 0.121945, 5.0, 5.0, 5.0, 5.0], [\"Dattr\", 1, 0.888744, 0.680548, 0.769715, 0.939794, 1.0, 1.0, 1.0, 1.0], [\"Dattr\", 2, 0.693393, 0.534848, 0.600481, 0.712974, 2.0, 2.0, 2.0, 2.0], [\"Dattr\", 3, 0.572395, 0.442427, 0.494783, 0.594078, 4.0, 4.0, 4.0, 4.0], [\"Dattr\", 4, 0.547548, 0.429899, 0.47531, 0.551373, 5.0, 5.0, 5.0, 5.0], [\"Dattr\", 5, 0.607828, 0.476404, 0.526087, 0.605187, 3.0, 3.0, 3.0, 3.0], [\"Eattr\", 1, 0.748575, 0.645197, 0.545002, 0.921587, 1.0, 1.0, 1.0, 1.0], [\"Eattr\", 2, 0.421454, 0.367652, 0.304832, 0.509385, 2.0, 2.0, 2.0, 2.0], [\"Eattr\", 3, 0.280357, 0.245557, 0.200532, 0.329618, 3.0, 3.0, 3.0, 3.0], [\"Eattr\", 4, 0.202577, 0.176622, 0.143074, 0.2366, 4.0, 4.0, 4.0, 4.0], [\"Eattr\", 5, 0.191674, 0.168298, 0.135101, 0.22503, 5.0, 5.0, 5.0, 5.0], [\"Fattr\", 1, 1.204729, 1.049461, 0.864676, 1.213175, 1.0, 1.0, 1.0, 1.0], [\"Fattr\", 2, 0.65699, 0.57659, 0.470211, 0.659341, 2.0, 2.0, 2.0, 2.0], [\"Fattr\", 3, 0.373902, 0.320841, 0.269375, 0.361384, 4.0, 4.0, 4.0, 4.0], [\"Fattr\", 4, 0.399748, 0.344361, 0.287104, 0.395752, 3.0, 3.0, 3.0, 3.0], [\"Fattr\", 5, 0.337583, 0.290839, 0.242656, 0.327599, 5.0, 5.0, 5.0, 5.0], [\"A1attr\", 1, 0.808674, 0.765984, 0.507067, 0.794958, 1.0, 1.0, 1.0, 1.0], [\"A1attr\", 2, 0.37429, 0.355426, 0.234288, 0.370316, 2.0, 2.0, 2.0, 2.0], [\"A1attr\", 3, 0.266329, 0.25285, 0.165481, 0.258577, 3.0, 3.0, 3.0, 3.0], [\"A1attr\", 4, 0.175307, 0.168011, 0.108135, 0.172551, 4.0, 4.0, 4.0, 4.0], [\"A1attr\", 5, 0.135193, 0.12846, 0.083958, 0.132826, 5.0, 5.0, 5.0, 5.0], [\"B2attr\", 1, 0.886679, 0.684225, 0.764478, 0.941072, 1.0, 1.0, 1.0, 1.0], [\"B2attr\", 2, 0.661366, 0.514349, 0.572113, 0.687697, 2.0, 2.0, 2.0, 2.0], [\"B2attr\", 3, 0.521073, 0.405629, 0.448977, 0.540078, 3.0, 3.0, 3.0, 3.0], [\"B2attr\", 4, 0.473155, 0.370634, 0.410748, 0.459748, 5.0, 5.0, 5.0, 5.0], [\"B2attr\", 5, 0.49562, 0.392056, 0.428443, 0.492944, 4.0, 4.0, 4.0, 4.0], [\"C3attr\", 1, 0.703903, 0.603773, 0.515456, 0.874168, 1.0, 1.0, 1.0, 1.0], [\"C3attr\", 2, 0.368937, 0.320226, 0.268888, 0.456167, 2.0, 2.0, 2.0, 2.0], [\"C3attr\", 3, 0.238642, 0.207302, 0.172686, 0.287329, 3.0, 3.0, 3.0, 3.0], [\"C3attr\", 4, 0.151909, 0.132326, 0.108308, 0.181647, 4.0, 4.0, 4. ...

# %%
import pandas as pd
import os
import scipy.stats as stats
import itertools

# Define the base path for SHAP files
shap_path = "/home/guillen/Conference Paper SHAP Maciej actualizado/Satimage/shap/"

# Load and combine the SHAP datasets into a single DataFrame
shap_aggregated = []
for j in range(1, 6):
    file_path = os.path.join(shap_path, f"lr_shap_aggregated_ir_{j}.parquet")
    df = pd.read_parquet(file_path)
    df["imbalance_ratio"] = j  # Add new column to track IR
    shap_aggregated.append(df)

# Concatenate all DataFrames into one
combined_shap_df = pd.concat(shap_aggregated, ignore_index=True)

import pandas as pd
import scipy.stats as stats
import itertools

# Select only the relevant columns for analysis
selected_columns = ['Aattr', 'Battr', 'Cattr', 'Dattr', 'Eattr', 'Fattr', 'A1attr',
       'B2attr', 'C3attr', 'D4attr', 'E5attr', 'F6attr', 'A7attr', 'B8attr',
       'C9attr', 'D10attr', 'E11attr', 'F12attr', 'A13attr', 'B14attr',
       'C15attr', 'D16attr', 'E17attr', 'F18attr', 'A19attr', 'B20attr',
       'C21attr', 'D22attr', 'E23attr', 'F24attr', 'A25attr', 'B26attr',
       'C27attr', 'D28attr', 'E29attr', 'F30attr', 'imbalance_ratio']

# Keep only the selected columns
combined_shap_df = combined_shap_df[selected_columns]

# Get unique IRs and features
imbalance_ratios = sorted(combined_shap_df['imbalance_ratio'].unique())
features = [col for col in selected_columns if col != 'imbalance_ratio']

# Dictionary to store rankings
rankings_dict = {feature: {} for feature in features}

for feature in features:
    # Compute mean value per IR
    means = combined_shap_df.groupby('imbalance_ratio')[feature].mean().sort_values(ascending=False)

    # Initialize significance matrix
    significance_matrix = pd.DataFrame(1.0, index=imbalance_ratios, columns=imbalance_ratios)

    # Pairwise t-tests
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        group1 = combined_shap_df[combined_shap_df['imbalance_ratio'] == ir1][feature]
        group2 = combined_shap_df[combined_shap_df['imbalance_ratio'] == ir2][feature]

        if len(group1) > 1 and len(group2) > 1:  # Ensure enough data
            stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)  # Welch’s t-test
        else:
            p_value = 1  # Assume no difference if insufficient data

        # Store p-value
        significance_matrix.loc[ir1, ir2] = p_value
        significance_matrix.loc[ir2, ir1] = p_value

    # Assign initial rankings based on means
    ranking_values = {ir: rank + 1 for rank, ir in enumerate(means.index)}

    # Adjust rankings if no significant differences
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        if significance_matrix.loc[ir1, ir2] >= 0.05:  # No significant difference
            min_rank = min(ranking_values[ir1], ranking_values[ir2])
            ranking_values[ir1] = ranking_values[ir2] = min_rank

    rankings_dict[feature] = ranking_values

# Convert to DataFrame
ranking_table = pd.DataFrame(rankings_dict).T.fillna(0)

# Reorder the DataFrame based on IR numeric values
sorted_columns = sorted(ranking_table.columns, key=lambda x: int(x))
ranking_table = ranking_table[sorted_columns]

# Function to adjust rankings so that ties do not skip numbers
def adjust_rankings(df):
    adjusted_df = df.copy()
    
    for feature in df.index:
        unique_ranks = sorted(set(df.loc[feature]))  # Get unique ranks in sorted order
        rank_mapping = {old_rank: new_rank + 1 for new_rank, old_rank in enumerate(unique_ranks)}  # Map old ranks to new continuous ranks
        
        # Apply mapping to adjust ranks
        adjusted_df.loc[feature] = df.loc[feature].map(rank_mapping)

    return adjusted_df

# Apply the function to adjust rankings
ranking_table = adjust_rankings(ranking_table)

# Save the ranking table locally
ranking_table.to_csv("ranking_medical_features_lr.csv", index=True)

# Display the ranking table
import ace_tools_open as tools
tools.display_dataframe_to_user(name="Adjusted Ranking of the mean by IR for Medical Features", dataframe=ranking_table)
# Out:
# Adjusted Ranking of the mean by IR for Medical Features
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4c3fff10_5912_4240_895b_c0b1e015b587"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.4 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4c3fff10_5912_4240_895b_c0b1e015b587:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>1</th>\n      <th>2</th>\n      <th>3</th>\n      <th>4</th>\n      <th>5</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Aattr\", 1, 2, 3, 4, 5], [\"Battr\", 1, 2, 3, 4, 5], [\"Cattr\", 1, 2, 3, 4, 5], [\"Dattr\", 1, 2, 4, 5, 3], [\"Eattr\", 1, 2, 3, 4, 5], [\"Fattr\", 1, 2, 4, 3, 5], [\"A1attr\", 1, 2, 3, 4, 5], [\"B2attr\", 1, 2, 3, 5, 4], [\"C3attr\", 1, 2, 3, 4, 5], [\"D4attr\", 1, 3, 2, 2, 2], [\"E5attr\", 1, 2, 3, 4, 5], [\"F6attr\", 1, 2, 3, 4, 4], [\"A7attr\", 1, 2, 3, 4, 5], [\"B8attr\", 1, 2, 3, 4, 5], [\"C9attr\", 1, 2, 3, 4, 5], [\"D10attr\", 1, 2, 3, 4, 4], [\"E11attr\", 1, 4, 2, 3, 4], [\"F12attr\", 1, 3, 3, 2, 3], [\"A13attr\", 1, 2, 3, 4, 5], [\"B14attr\", 1, 3, 2, 2, 2], [\"C15attr\", 1, 2, 3, 3, 3], [\"D16attr\", 1, 2, 3, 4, 4], [\"E17attr\", 1, 2, 3, 4, 5], [\"F18attr\", 1, 2, 3, 3, 3], [\"A19attr\", 1, 2, 3, 3, 3], [\"B20attr\", 1, 2, 3, 4, 4], [\"C21attr\", 1, 2, 3, 4, 5], [\"D22attr\", 1, 2, 3, 4, 4], [\"E23attr\", 1, 2, 3, 4, 5], [\"F24attr\", 1, 2, 3, 4, 5], [\"A25attr\", 1, 2, 3, 5, 4], [\"B26attr\", 1, 2, 3, 4, 5], [\"C27attr\", 1, 2, 3, 3, 4], [\"D28attr\", 1, 2, 3, 2, 3], [\"E29attr\", 1, 2, 3, 4, 5], [\"F30attr\", 1, 2, 3, 5, 4]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
import pandas as pd
import scipy.stats as stats
import itertools

# Select only the relevant medical features and imbalance ratio
selected_columns = ['Aattr', 'Battr', 'Cattr', 'Dattr', 'Eattr', 'Fattr', 'A1attr',
       'B2attr', 'C3attr', 'D4attr', 'E5attr', 'F6attr', 'A7attr', 'B8attr',
       'C9attr', 'D10attr', 'E11attr', 'F12attr', 'A13attr', 'B14attr',
       'C15attr', 'D16attr', 'E17attr', 'F18attr', 'A19attr', 'B20attr',
       'C21attr', 'D22attr', 'E23attr', 'F24attr', 'A25attr', 'B26attr',
       'C27attr', 'D28attr', 'E29attr', 'F30attr', 'imbalance_ratio']

# Keep only the selected columns
combined_shap_df = combined_shap_df[selected_columns]

# Get unique IRs and features
imbalance_ratios = sorted(combined_shap_df['imbalance_ratio'].unique())
features = [col for col in selected_columns if col != 'imbalance_ratio']

# Dictionary to store rankings based on standard deviation
rankings_std_dict = {feature: {} for feature in features}

for feature in features:
    # Compute standard deviation per IR
    std_devs = combined_shap_df.groupby('imbalance_ratio')[feature].std().sort_values(ascending=False)

    # Initialize significance matrix
    significance_matrix = pd.DataFrame(1.0, index=imbalance_ratios, columns=imbalance_ratios)

    # Pairwise Levene's test for variance comparison
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        group1 = combined_shap_df[combined_shap_df['imbalance_ratio'] == ir1][feature]
        group2 = combined_shap_df[combined_shap_df['imbalance_ratio'] == ir2][feature]

        if len(group1) > 1 and len(group2) > 1:  # Ensure enough data
            stat, p_value = stats.levene(group1, group2, center='median')  # Levene’s test for variance
        else:
            p_value = 1  # Assume no difference if insufficient data

        # Store p-value
        significance_matrix.loc[ir1, ir2] = p_value
        significance_matrix.loc[ir2, ir1] = p_value

    # Assign initial rankings based on standard deviations
    ranking_values = {ir: rank + 1 for rank, ir in enumerate(std_devs.index)}

    # Adjust rankings if no significant differences
    for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
        if significance_matrix.loc[ir1, ir2] >= 0.05:  # No significant difference
            min_rank = min(ranking_values[ir1], ranking_values[ir2])
            ranking_values[ir1] = ranking_values[ir2] = min_rank

    rankings_std_dict[feature] = ranking_values

# Convert to DataFrame
ranking_std_table = pd.DataFrame(rankings_std_dict).T.fillna(0)

# Reorder the DataFrame based on IR numeric values
sorted_columns = sorted(ranking_std_table.columns, key=lambda x: int(x))
ranking_std_table = ranking_std_table[sorted_columns]

# Function to adjust rankings so that ties do not skip numbers
def adjust_rankings(df):
    adjusted_df = df.copy()
    
    for feature in df.index:
        unique_ranks = sorted(set(df.loc[feature]))  # Get unique ranks in sorted order
        rank_mapping = {old_rank: new_rank + 1 for new_rank, old_rank in enumerate(unique_ranks)}  # Map old ranks to new continuous ranks
        
        # Apply mapping to adjust ranks
        adjusted_df.loc[feature] = df.loc[feature].map(rank_mapping)

    return adjusted_df

# Apply the function to adjust rankings
ranking_std_table = adjust_rankings(ranking_std_table)

# Save the ranking table locally
ranking_std_table.to_csv("ranking_variance_medical_features_lr.csv", index=True)

# Display the updated ranking table
import ace_tools_open as tools
tools.display_dataframe_to_user(name="Adjusted Ranking of the variance by IR for Medical Features", dataframe=ranking_std_table)
# Out:
# Adjusted Ranking of the variance by IR for Medical Features
# <!--| quarto-html-table-processing: none -->
# <table id="itables_0fd9f028_5d03_4562_b680_b1baddf74727"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.4 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_0fd9f028_5d03_4562_b680_b1baddf74727:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>1</th>\n      <th>2</th>\n      <th>3</th>\n      <th>4</th>\n      <th>5</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Aattr\", 1, 2, 3, 4, 5], [\"Battr\", 1, 2, 3, 4, 5], [\"Cattr\", 1, 2, 3, 4, 5], [\"Dattr\", 1, 2, 4, 5, 3], [\"Eattr\", 1, 2, 3, 4, 5], [\"Fattr\", 1, 2, 4, 3, 5], [\"A1attr\", 1, 2, 3, 4, 5], [\"B2attr\", 1, 2, 3, 5, 4], [\"C3attr\", 1, 2, 3, 4, 5], [\"D4attr\", 1, 3, 2, 2, 2], [\"E5attr\", 1, 2, 3, 4, 5], [\"F6attr\", 1, 2, 3, 4, 4], [\"A7attr\", 1, 2, 3, 4, 5], [\"B8attr\", 1, 2, 3, 4, 5], [\"C9attr\", 1, 2, 3, 4, 5], [\"D10attr\", 1, 2, 3, 4, 4], [\"E11attr\", 1, 4, 2, 3, 5], [\"F12attr\", 1, 3, 3, 2, 3], [\"A13attr\", 1, 2, 3, 4, 5], [\"B14attr\", 1, 3, 2, 2, 2], [\"C15attr\", 1, 2, 3, 4, 4], [\"D16attr\", 1, 2, 3, 4, 4], [\"E17attr\", 1, 2, 3, 4, 5], [\"F18attr\", 1, 2, 3, 3, 3], [\"A19attr\", 1, 2, 3, 3, 3], [\"B20attr\", 1, 2, 3, 4, 4], [\"C21attr\", 1, 2, 3, 4, 5], [\"D22attr\", 1, 2, 3, 4, 4], [\"E23attr\", 1, 2, 3, 4, 5], [\"F24attr\", 1, 2, 3, 4, 5], [\"A25attr\", 1, 2, 3, 4, 4], [\"B26attr\", 1, 2, 3, 4, 5], [\"C27attr\", 1, 2, 3, 4, 5], [\"D28attr\", 1, 2, 3, 2, 3], [\"E29attr\", 1, 2, 3, 4, 5], [\"F30attr\", 1, 2, 3, 4, 4]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
plt.figure(figsize=(12, 6))
for ir in ranking_df["IR"].unique():
    subset = ranking_df[ranking_df["IR"] == ir]
#     plt.scatter(subset["feature"], subset["median"], label=f"{ir} (median)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["mean"], label=f"{ir} (mean)", alpha=0.7)
    plt.scatter(subset["feature"], subset["std"], label=f"{ir} (std)", alpha=0.7)
#     plt.scatter(subset["feature"], subset["iqr"], label=f"{ir} (iqr)", alpha=0.7)

plt.xticks(rotation=90)
plt.title("Dotted Chart for STD by Imbalance Ratio")
plt.ylabel("Values")
plt.xlabel("Features")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# ***
# ***
# ***
# ## Features ranking based on position/order/significance

# %%
sorted_orderScore[:3]
# Out:
#       imbalanceRatio                       Subset  Indicator  \
# 0  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19  orderMean
# 1  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19   orderStd
# 2  lr_shap_list_ir_5  lr_shap_list_ir_5_subset_19   orderSum
#
#                                      Sorted_Features
# 0  ['F12attr', 'B14attr', 'D4attr', 'F18attr', 'C...
# 1  ['B14attr', 'F12attr', 'F18attr', 'D4attr', 'B...
# 2  ['F12attr', 'B14attr', 'D4attr', 'F18attr', 'C...

# %%
sorted_orderScore[sorted_orderScore['Indicator']=='orderMean'][['imbalanceRatio', 'Subset', 'Indicator', 'Sorted_Features']]
# Out:
#          imbalanceRatio                        Subset  Indicator  \
# 0     lr_shap_list_ir_5   lr_shap_list_ir_5_subset_19  orderMean
# 3     lr_shap_list_ir_3   lr_shap_list_ir_3_subset_39  orderMean
# 6     lr_shap_list_ir_1  lr_shap_list_ir_1_subset_100  orderMean
# 9     lr_shap_list_ir_4   lr_shap_list_ir_4_subset_55  orderMean
# 12    lr_shap_list_ir_1   lr_shap_list_ir_1_subset_68  orderMean
# ...                 ...                           ...        ...
# 1515  lr_shap_list_ir_4   lr_shap_list_ir_4_subset_19  orderMean
# 1518  lr_shap_list_ir_2   lr_shap_list_ir_2_subset_98  orderMean
# 1521  lr_shap_list_ir_3  lr_shap_list_ir_3_subset_102  orderMean
# 1524  lr_shap_list_ir_4   lr_shap_list_ir_4_subset_76  orderMean
# 1527  lr_shap_list_ir_2   lr_shap_list_ir_2_subset_88  orderMean
#
#                                         Sorted_Features
# 0     ['F12attr', 'B14attr', 'D4attr', 'F18attr', 'C...
# 3     ['D4attr', 'F12attr', 'D22attr', 'E11attr', 'B...
# 6     ['Eattr', 'F24attr', 'E23attr', 'F18attr', 'Ca...
# 9     ['F12attr', 'D4attr', 'B14attr', 'Fattr', 'D28...
# 12    ['B20attr', 'C9attr', 'B26attr', 'D22attr', 'E...
# ...                                                 ...
# 1515  ['F12attr', 'E11attr', 'B20attr', 'B14attr', '...
# 1518  ['F12attr', 'B8attr', 'B20attr', 'E11attr', 'D...
# 1521  ['B14attr', 'F12attr', 'F18attr', 'D4attr', 'E...
# 1524  ['F18attr', 'D28attr', 'F12attr', 'D4attr', 'E...
# 1527  ['F12attr', 'B14attr', 'F18attr', 'B2attr', 'D...
#
# [510 rows x 4 columns]

# %%
import pandas as pd

def extract_top_features(dataframe, column_name, top_features_amount):
    """
    Extract the top X features from the specified column in the DataFrame and add them as a new column.

    Parameters:
        dataframe (pd.DataFrame): Input DataFrame.
        column_name (str): Name of the column containing feature lists as strings.
        top_features_amount (int): Number of top features to extract.

    Returns:
        pd.DataFrame: DataFrame with an additional column containing the top X features as lists.
    """
    dataframe[f'top_{top_features_amount}_features'] = dataframe[column_name].apply(
        lambda x: eval(x)[:top_features_amount]
    )
    return dataframe

# %%
# use of extract_top_features 
df = sorted_orderScore[sorted_orderScore['Indicator']=='orderMean'][['imbalanceRatio', 'Subset', 'Indicator', 'Sorted_Features']].copy()

# Define the number of top features to extract
top_features_amount = 5

# Apply the function to extract top features
orderIndicator = extract_top_features(df, "Sorted_Features", top_features_amount)

# %%
def calculate_unique_feature_lists_per_group(dataframe, group_column, list_column):
    """
    Calculate unique lists in the specified column of the DataFrame for each group.

    Parameters:
        dataframe (pd.DataFrame): Input DataFrame.
        group_column (str): Name of the column to group by.
        list_column (str): Name of the column containing feature lists as strings or lists.

    Returns:
        pd.DataFrame: DataFrame with columns for group values and unique feature lists.
    """
    unique_lists_per_group = []

    # Group by the specified column
    for group, group_df in dataframe.groupby(group_column):
        # Convert each list in the column to a tuple (to account for order sensitivity) and collect unique tuples
        unique_lists = set(tuple(row) for row in group_df[list_column].apply(lambda x: eval(x) if isinstance(x, str) else x))
        for unique_list in unique_lists:
            unique_lists_per_group.append({group_column: group, "unique_feature_list": unique_list})

    return pd.DataFrame(unique_lists_per_group)

# %%
orderIndicator
# Out:
#          imbalanceRatio                        Subset  Indicator  \
# 0     lr_shap_list_ir_5   lr_shap_list_ir_5_subset_19  orderMean
# 3     lr_shap_list_ir_3   lr_shap_list_ir_3_subset_39  orderMean
# 6     lr_shap_list_ir_1  lr_shap_list_ir_1_subset_100  orderMean
# 9     lr_shap_list_ir_4   lr_shap_list_ir_4_subset_55  orderMean
# 12    lr_shap_list_ir_1   lr_shap_list_ir_1_subset_68  orderMean
# ...                 ...                           ...        ...
# 1515  lr_shap_list_ir_4   lr_shap_list_ir_4_subset_19  orderMean
# 1518  lr_shap_list_ir_2   lr_shap_list_ir_2_subset_98  orderMean
# 1521  lr_shap_list_ir_3  lr_shap_list_ir_3_subset_102  orderMean
# 1524  lr_shap_list_ir_4   lr_shap_list_ir_4_subset_76  orderMean
# 1527  lr_shap_list_ir_2   lr_shap_list_ir_2_subset_88  orderMean
#
#                                         Sorted_Features  \
# 0     ['F12attr', 'B14attr', 'D4attr', 'F18attr', 'C...
# 3     ['D4attr', 'F12attr', 'D22attr', 'E11attr', 'B...
# 6     ['Eattr', 'F24attr', 'E23attr', 'F18attr', 'Ca...
# 9     ['F12attr', 'D4attr', 'B14attr', 'Fattr', 'D28...
# 12    ['B20attr', 'C9attr', 'B26attr', 'D22attr', 'E...
# ...                                                 ...
# 1515  ['F12attr', 'E11attr', 'B20attr', 'B14attr', '...
# 1518  ['F12attr', 'B8attr', 'B20attr', 'E11attr', 'D...
# 1521  ['B14attr', 'F12attr', 'F18attr', 'D4attr', 'E...
# 1524  ['F18attr', 'D28attr', 'F12attr', 'D4attr', 'E...
# 1527  ['F12attr', 'B14attr', 'F18attr', 'B2attr', 'D...
#
#                                     top_5_features
# 0     [F12attr, B14attr, D4attr, F18attr, C15attr]
# 3     [D4attr, F12attr, D22attr, E11attr, B20attr]
# 6        [Eattr, F24attr, E23attr, F18attr, Cattr]
# 9       [F12attr, D4attr, B14attr, Fattr, D28attr]
# 12    [B20attr, C9attr, B26attr, D22attr, E11attr]
# ...                                            ...
# 1515  [F12attr, E11attr, B20attr, B14attr, D4attr]
# 1518  [F12attr, B8attr, B20attr, E11attr, D28attr]
# 1521  [B14attr, F12attr, F18attr, D4attr, E11attr]
# 1524  [F18attr, D28attr, F12attr, D4attr, E11attr]
# 1527   [F12attr, B14attr, F18attr, B2attr, D4attr]
#
# [510 rows x 5 columns]

# %%
df = orderIndicator.copy()

# Calculate unique feature lists for each imbalanceRatio
unique_feature_lists_df = calculate_unique_feature_lists_per_group(df, "imbalanceRatio", "top_5_features")

# %%
unique_feature_lists_df
# Out:
#         imbalanceRatio                           unique_feature_list
# 0    lr_shap_list_ir_1     (F12attr, B8attr, Dattr, A1attr, F18attr)
# 1    lr_shap_list_ir_1  (F12attr, B20attr, D4attr, F18attr, C15attr)
# 2    lr_shap_list_ir_1    (B14attr, Fattr, E11attr, D4attr, B26attr)
# 3    lr_shap_list_ir_1    (B26attr, D16attr, D4attr, Fattr, B14attr)
# 4    lr_shap_list_ir_1  (D4attr, D22attr, D16attr, F12attr, B14attr)
# ..                 ...                                           ...
# 476  lr_shap_list_ir_5   (D4attr, E11attr, F18attr, F12attr, B2attr)
# 477  lr_shap_list_ir_5  (B14attr, D4attr, F12attr, E11attr, D28attr)
# 478  lr_shap_list_ir_5  (F12attr, D4attr, E11attr, B14attr, F18attr)
# 479  lr_shap_list_ir_5    (F18attr, D4attr, F12attr, Dattr, C15attr)
# 480  lr_shap_list_ir_5  (F12attr, D4attr, D28attr, C15attr, B14attr)
#
# [481 rows x 2 columns]

# %%
def add_presence_columns(unique_feature_lists_df, dataframe, group_column, list_column):
    """
    Add new columns to the unique_feature_lists_df for each unique value in the group column.
    Each column indicates the presence (1) or absence (0) of the unique feature list in the original DataFrame's groups.

    Parameters:
        unique_feature_lists_df (pd.DataFrame): DataFrame with unique feature lists.
        dataframe (pd.DataFrame): Original DataFrame.
        group_column (str): Name of the column to group by.
        list_column (str): Name of the column containing feature lists as strings or lists.

    Returns:
        pd.DataFrame: Updated unique_feature_lists_df with new columns.
    """
    group_values = dataframe[group_column].unique()

    for group in group_values:
        group_features = set(
            tuple(row) for row in dataframe[dataframe[group_column] == group][list_column].apply(lambda x: eval(x) if isinstance(x, str) else x)
        )

        unique_feature_lists_df[group] = unique_feature_lists_df["unique_feature_list"].apply(
            lambda x: 1 if x in group_features else 0
        )

    return unique_feature_lists_df

# %%
unique_feature_lists_df
# Out:
#         imbalanceRatio                           unique_feature_list
# 0    lr_shap_list_ir_1     (F12attr, B8attr, Dattr, A1attr, F18attr)
# 1    lr_shap_list_ir_1  (F12attr, B20attr, D4attr, F18attr, C15attr)
# 2    lr_shap_list_ir_1    (B14attr, Fattr, E11attr, D4attr, B26attr)
# 3    lr_shap_list_ir_1    (B26attr, D16attr, D4attr, Fattr, B14attr)
# 4    lr_shap_list_ir_1  (D4attr, D22attr, D16attr, F12attr, B14attr)
# ..                 ...                                           ...
# 476  lr_shap_list_ir_5   (D4attr, E11attr, F18attr, F12attr, B2attr)
# 477  lr_shap_list_ir_5  (B14attr, D4attr, F12attr, E11attr, D28attr)
# 478  lr_shap_list_ir_5  (F12attr, D4attr, E11attr, B14attr, F18attr)
# 479  lr_shap_list_ir_5    (F18attr, D4attr, F12attr, Dattr, C15attr)
# 480  lr_shap_list_ir_5  (F12attr, D4attr, D28attr, C15attr, B14attr)
#
# [481 rows x 2 columns]

# %%
unique_feature_lists_df = add_presence_columns(unique_feature_lists_df, unique_feature_lists_df, "imbalanceRatio", "unique_feature_list")

# %%
imbalanceRatio_columns = list(unique_feature_lists_df['imbalanceRatio'].unique())

# %%
imbalanceRatio_columns
# Out:
# ['lr_shap_list_ir_1',
#  'lr_shap_list_ir_2',
#  'lr_shap_list_ir_3',
#  'lr_shap_list_ir_4',
#  'lr_shap_list_ir_5']

# %%
def add_sum_column(unique_feature_lists_df, imbalanceRatio_columns):
    """
    Add a new column 'sum' to the DataFrame which sums values across specified imbalanceRatio columns.

    Parameters:
        unique_feature_lists_df (pd.DataFrame): DataFrame with unique feature lists and imbalanceRatio columns.
        imbalanceRatio_columns (list): List of column names to sum across.

    Returns:
        pd.DataFrame: Updated unique_feature_lists_df with the 'sum' column.
    """
    unique_feature_lists_df['sum'] = unique_feature_lists_df[imbalanceRatio_columns].sum(axis=1)
    return unique_feature_lists_df

# %%
unique_feature_lists_df = add_sum_column(unique_feature_lists_df, imbalanceRatio_columns)

# %%
unique_feature_lists_df
# Out:
#         imbalanceRatio                           unique_feature_list  \
# 0    lr_shap_list_ir_1     (F12attr, B8attr, Dattr, A1attr, F18attr)
# 1    lr_shap_list_ir_1  (F12attr, B20attr, D4attr, F18attr, C15attr)
# 2    lr_shap_list_ir_1    (B14attr, Fattr, E11attr, D4attr, B26attr)
# 3    lr_shap_list_ir_1    (B26attr, D16attr, D4attr, Fattr, B14attr)
# 4    lr_shap_list_ir_1  (D4attr, D22attr, D16attr, F12attr, B14attr)
# ..                 ...                                           ...
# 476  lr_shap_list_ir_5   (D4attr, E11attr, F18attr, F12attr, B2attr)
# 477  lr_shap_list_ir_5  (B14attr, D4attr, F12attr, E11attr, D28attr)
# 478  lr_shap_list_ir_5  (F12attr, D4attr, E11attr, B14attr, F18attr)
# 479  lr_shap_list_ir_5    (F18attr, D4attr, F12attr, Dattr, C15attr)
# 480  lr_shap_list_ir_5  (F12attr, D4attr, D28attr, C15attr, B14attr)
#
#      lr_shap_list_ir_1  lr_shap_list_ir_2  lr_shap_list_ir_3  \
# 0                    1                  0                  0
# 1                    1                  0                  0
# 2                    1                  0                  0
# 3                    1                  0                  0
# 4                    1                  0                  0
# ..                 ...                ...                ...
# 476                  0                  0                  0
# 477                  0                  0                  0
# 478                  0                  0                  0
# 479                  0                  0                  0
# 480                  0                  0                  0
#
#      lr_shap_list_ir_4  lr_shap_list_ir_5  sum
# 0                    0                  0    1
# 1                    0                  0    1
# 2                    0                  0    1
# 3                    0                  0    1
# 4                    0                  0    1
# ..                 ...                ...  ...
# 476                  0                  1    1
# 477                  0                  1    1
# 478                  0                  1    1
# 479                  0                  1    1
# 480                  0                  1    1
#
# [481 rows x 8 columns]

# %%
# %%time

# Create histograms for each IR, to evaluate how many unique sets of the most important features was made
for ir_name in imbalanceRatio_columns:
    plt.figure(figsize=(6, 4))  # Set figure size
    plt.hist(unique_feature_lists_df[unique_feature_lists_df['imbalanceRatio']==ir_name]['sum'], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Histogram for {ir_name}')
    plt.xlabel('occurence of top5 features set in diffrent IR')
    plt.ylabel('Amount of unique top5 sets')
    plt.grid(True)
    plt.show()

    
    # Save the histogram as a PNG file in the specified folder
#     filename = os.path.join(output_folder, f"Histogram_for_{feature.replace(' ', '_')}.png")  # Replace spaces with underscores for filenames
#     plt.savefig(filename, dpi=300, bbox_inches='tight')
# Out:
# CPU times: user 2.24 s, sys: 50.8 ms, total: 2.3 s
# Wall time: 36.3 s

# %%
import matplotlib.pyplot as plt
import numpy as np

rank_colors = {1: 'blue', 2: 'green', 3: 'yellow', 4: 'orange', 5: 'red'}
ir_names = unique_feature_lists_df['imbalanceRatio'].unique()
x_values = np.arange(1, 6) 
plt.figure(figsize=(10, 6))

for ir_idx, ir_name in enumerate(ir_names):
    
    rank_counts = [np.sum(unique_feature_lists_df[unique_feature_lists_df['imbalanceRatio'] == ir_name]['sum'] == x) for x in x_values]
    plt.plot(x_values, rank_counts, marker='o', linestyle='-', color=rank_colors.get(ir_idx + 1, 'gray'), label=ir_name)

plt.xlabel('Number of occurrences')
plt.ylabel('Frequency')
plt.title('Repetition of unique Top-5 feature sets across subsets for each IR')
plt.xticks(x_values) 
plt.yticks(np.arange(0, 81 + 10, 10))

plt.legend(title="Imbalance Ratios", loc="upper right")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# - Results shows that growing imbalance IR5 => IR1 is shown in different sets of the most significant features.
#     - For IR1 models have 40 new, unique sets of the most important features;
#     - for IR3 (and less) there is no unique sets for that imbalance ratio
# - there is a trend of less amount of different sets of the most important features, only 8 for IR5, and

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
file_path = "shap_orderScore_lr.csv"
df = pd.read_csv(file_path)

# Filter only rows where Indicator is 'orderMean'
filtered_df = df[df['Indicator'] == 'orderMean'][['imbalanceRatio', 'Subset', 'Sorted_Features']].copy()

# Function to extract top N features from the Sorted_Features column
def extract_top_features(dataframe, column_name, top_features_amount):
    dataframe[f'top_{top_features_amount}_features'] = dataframe[column_name].apply(
        lambda x: eval(x)[:top_features_amount] if isinstance(x, str) else x[:top_features_amount]
    )
    return dataframe

# Apply the function for top 1 to 5 features
for top_n in range(1, 6):
    filtered_df = extract_top_features(filtered_df, "Sorted_Features", top_n)

# Function to calculate unique feature lists per group
def calculate_unique_feature_lists_per_group(dataframe, group_column, list_column):
    unique_lists_per_group = []
    
    for group, group_df in dataframe.groupby(group_column):
        unique_lists = set(tuple(row) for row in group_df[list_column])
        for unique_list in unique_lists:
            unique_lists_per_group.append({group_column: group, "unique_feature_list": unique_list})
    
    return pd.DataFrame(unique_lists_per_group)

# Process unique feature lists for different top feature amounts
unique_feature_lists = {}
for top_n in range(1, 6):
    unique_feature_lists[top_n] = calculate_unique_feature_lists_per_group(
        filtered_df, "imbalanceRatio", f"top_{top_n}_features"
    )

# Function to add presence columns per imbalance ratio
def add_presence_columns(unique_feature_lists_df, dataframe, group_column, list_column):
    group_values = dataframe[group_column].unique()

    for group in group_values:
        group_features = set(tuple(row) for row in dataframe[dataframe[group_column] == group][list_column])
        unique_feature_lists_df[group] = unique_feature_lists_df["unique_feature_list"].apply(
            lambda x: 1 if x in group_features else 0
        )

    return unique_feature_lists_df

# Add presence columns for each unique feature list dataframe
for top_n in range(1, 6):
    unique_feature_lists[top_n] = add_presence_columns(
        unique_feature_lists[top_n], filtered_df, "imbalanceRatio", f"top_{top_n}_features"
    )

# Summarize occurrences
for top_n in range(1, 6):
    imbalanceRatio_columns = list(unique_feature_lists[top_n]['imbalanceRatio'].unique())
    unique_feature_lists[top_n]['sum'] = unique_feature_lists[top_n][imbalanceRatio_columns].sum(axis=1)

# Generate line plot for unique feature sets appearing exactly once
plt.figure(figsize=(10, 6))
x_values = np.arange(1, 6)  # 1 to 5 features

for ir_name in filtered_df['imbalanceRatio'].unique():
    rank_counts = [
        np.sum(unique_feature_lists[top_n][unique_feature_lists[top_n]['imbalanceRatio'] == ir_name]['sum'] == 1)
        for top_n in range(1, 6)
    ]
    plt.plot(x_values, rank_counts, marker='o', linestyle='-', label=ir_name)

plt.xlabel('Top-N Features')
plt.ylabel('Number of Unique Feature Sets Appearing Once')
plt.title('Repetition of Unique Top Features Across Subsets for Each Imbalance Ratio')
plt.xticks(x_values)
plt.legend(title="Imbalance Ratios", loc="upper left")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
from scipy.stats import entropy
from sklearn.preprocessing import MultiLabelBinarizer

# Cargar el dataset
file_path = "shap_orderScore_lr.csv"
df = pd.read_csv(file_path)

# Filtrar los datos donde el indicador es 'orderMean'
filtered_df = df[df['Indicator'] == 'orderMean'][['imbalanceRatio', 'Subset', 'Sorted_Features']].copy()

# Función para extraer las k-top características de la columna Sorted_Features
def extract_top_features(dataframe, column_name, top_features_amount):
    dataframe[f'top_{top_features_amount}_features'] = dataframe[column_name].apply(
        lambda x: eval(x)[:top_features_amount] if isinstance(x, str) else x[:top_features_amount]
    )
    return dataframe

# Aplicar la función para los k-top features (k = 1 a 5)
for top_n in range(1, 6):
    filtered_df = extract_top_features(filtered_df, "Sorted_Features", top_n)

# Función para calcular la tasa de variabilidad de conjuntos de características por IR
def calculate_feature_set_variability(dataframe, group_column, list_column):
    variability_dict = {}
    
    for group, group_df in dataframe.groupby(group_column):
        unique_sets = set(tuple(row) for row in group_df[list_column])
        total_sets = len(group_df)
        variability_dict[group] = len(unique_sets) / total_sets  # Ratio de variabilidad
    
    return pd.DataFrame(list(variability_dict.items()), columns=[group_column, 'variability'])

# Función para calcular la similitud de Jaccard promedio entre subsets del mismo IR (corregida)
def calculate_jaccard_similarity(dataframe, group_column, list_column):
    jaccard_dict = {}

    for group, group_df in dataframe.groupby(group_column):
        feature_sets = [set(row) for row in group_df[list_column]]
        
        if len(feature_sets) > 1:
            # Convertir los conjuntos en una matriz binaria usando MultiLabelBinarizer
            mlb = MultiLabelBinarizer()
            binary_matrix = mlb.fit_transform(feature_sets)
            
            # Calcular la distancia de Jaccard correctamente
            jaccard_matrix = 1 - squareform(pdist(binary_matrix, metric='jaccard'))
            avg_jaccard = np.mean(jaccard_matrix[np.triu_indices(len(feature_sets), k=1)])  # Promedio sin la diagonal
        else:
            avg_jaccard = 1  # Si hay solo un subset, la similaridad es 1
        
        jaccard_dict[group] = avg_jaccard
    
    return pd.DataFrame(list(jaccard_dict.items()), columns=[group_column, 'jaccard_similarity'])

# Función para calcular la entropía de los sets de características en cada IR
def calculate_entropy(dataframe, group_column, list_column):
    entropy_dict = {}

    for group, group_df in dataframe.groupby(group_column):
        feature_sets = [tuple(row) for row in group_df[list_column]]
        _, counts = np.unique(feature_sets, return_counts=True)
        prob_dist = counts / counts.sum()
        entropy_value = entropy(prob_dist)  # Entropía de Shannon
        entropy_dict[group] = entropy_value

    return pd.DataFrame(list(entropy_dict.items()), columns=[group_column, 'entropy'])

# Calcular las métricas para k = 1 a 5
results = {}

for top_n in range(1, 6):
    results[top_n] = {
        'variability': calculate_feature_set_variability(filtered_df, "imbalanceRatio", f"top_{top_n}_features"),
        'jaccard': calculate_jaccard_similarity(filtered_df, "imbalanceRatio", f"top_{top_n}_features"),
        'entropy': calculate_entropy(filtered_df, "imbalanceRatio", f"top_{top_n}_features")
    }

# Graficar resultados
plt.figure(figsize=(15, 5))

for i, (metric_name, ylabel) in enumerate(zip(['variability', 'jaccard', 'entropy'],
                                              ['Feature Set Variability', 'Average Jaccard Similarity', 'Feature Set Entropy'])):
    plt.subplot(1, 3, i + 1)
    x_values = np.arange(1, 6)
    
    for ir_name in filtered_df['imbalanceRatio'].unique():
        y_values = [results[top_n][metric_name].set_index("imbalanceRatio").loc[ir_name].values[0] for top_n in range(1, 6)]
        plt.plot(x_values, y_values, marker='o', linestyle='-', label=f'IR {ir_name}')
    
    plt.xlabel('Top-N Features')
    plt.ylabel(ylabel)
    plt.title(ylabel + ' Across IRs')
    plt.xticks(x_values)
    plt.legend(title="Imbalance Ratios", loc="best")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import entropy

# Cargar el dataset
file_path = "shap_orderScore_lr.csv"
df = pd.read_csv(file_path)

# Filtrar los datos donde el indicador es 'orderMean'
filtered_df = df[df['Indicator'] == 'orderMean'][['imbalanceRatio', 'Subset', 'Sorted_Features']].copy()

# Función para extraer las k-top características de la columna Sorted_Features
def extract_top_features(dataframe, column_name, top_features_amount):
    dataframe[f'top_{top_features_amount}_features'] = dataframe[column_name].apply(
        lambda x: eval(x)[:top_features_amount] if isinstance(x, str) else x[:top_features_amount]
    )
    return dataframe

# Aplicar la función para los k-top features (k = 1 a 5)
for top_n in range(1, 6):
    filtered_df = extract_top_features(filtered_df, "Sorted_Features", top_n)

# Función para calcular la entropía de los sets de características en cada IR
def calculate_entropy(dataframe, group_column, list_column):
    entropy_dict = {}

    for group, group_df in dataframe.groupby(group_column):
        feature_sets = [tuple(row) for row in group_df[list_column]]
        _, counts = np.unique(feature_sets, return_counts=True)
        prob_dist = counts / counts.sum()
        entropy_value = entropy(prob_dist)  # Entropía de Shannon
        entropy_dict[group] = entropy_value

    return pd.DataFrame(list(entropy_dict.items()), columns=[group_column, 'entropy'])

# Calcular la entropía para k = 1 a 5
entropy_results = {}

for top_n in range(1, 6):
    entropy_results[top_n] = calculate_entropy(filtered_df, "imbalanceRatio", f"top_{top_n}_features")

# Graficar solo la entropía sin título y guardarlo en 600 dpi
plt.figure(figsize=(7, 5))
x_values = np.arange(1, 6)

for ir_name in filtered_df['imbalanceRatio'].unique():
    y_values = [entropy_results[top_n].set_index("imbalanceRatio").loc[ir_name].values[0] for top_n in range(1, 6)]
    plt.plot(x_values, y_values, marker='o', linestyle='-', label=f'IR {ir_name}')

plt.xlabel('Top-N Features')
plt.ylabel('Entropy')
plt.xticks(x_values)
plt.legend(title="IRs", loc="best")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Guardar la figura a 600 dpi
entropy_plot_path = "entropy_plot_lr.png"
plt.savefig(entropy_plot_path, dpi=600, bbox_inches='tight')

# Mostrar el path de la imagen generada
entropy_plot_path
# Out:
# 'entropy_plot_lr.png'

# %%
# Definir los nombres de los IRs según la especificación
shap_list_labels = ['1:49', '1:19', '1:9', '3:17', '1:4']

# Graficar solo la entropía con los IRs correctamente etiquetados
plt.figure(figsize=(5, 3.5))
x_values = np.arange(1, 6)

for ir_name, label in zip(filtered_df['imbalanceRatio'].unique(), shap_list_labels):
    y_values = [entropy_results[top_n].set_index("imbalanceRatio").loc[ir_name].values[0] for top_n in range(1, 6)]
    plt.plot(x_values, y_values, marker='o', linestyle='-', label=f'{label}')

plt.xlabel('Top-N Features')
plt.ylabel('Entropy')
plt.xticks(x_values)
plt.legend(title="IRs", loc="lower right")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Guardar la figura a 600 dpi con etiquetas de IR corregidas
entropy_plot_path = "entropy_plot_corrected_lr.png"
plt.savefig(entropy_plot_path, dpi=600, bbox_inches='tight')

# Proporcionar el enlace de descarga
entropy_plot_path
# Out:
# 'entropy_plot_corrected_lr.png'

# %%
entropy_results
# Out:
# {1:       imbalanceRatio   entropy
#  0  lr_shap_list_ir_1  2.699351
#  1  lr_shap_list_ir_2  2.050758
#  2  lr_shap_list_ir_3  1.556707
#  3  lr_shap_list_ir_4  0.882469
#  4  lr_shap_list_ir_5  0.523474,
#  2:       imbalanceRatio   entropy
#  0  lr_shap_list_ir_1  2.980435
#  1  lr_shap_list_ir_2  2.629072
#  2  lr_shap_list_ir_3  1.925843
#  3  lr_shap_list_ir_4  1.676609
#  4  lr_shap_list_ir_5  1.398511,
#  3:       imbalanceRatio   entropy
#  0  lr_shap_list_ir_1  3.180743
#  1  lr_shap_list_ir_2  2.807625
#  2  lr_shap_list_ir_3  2.191570
#  3  lr_shap_list_ir_4  1.949265
#  4  lr_shap_list_ir_5  1.741258,
#  4:       imbalanceRatio   entropy
#  0  lr_shap_list_ir_1  3.266321
#  1  lr_shap_list_ir_2  2.947461
#  2  lr_shap_list_ir_3  2.355042
#  3  lr_shap_list_ir_4  2.081598
#  4  lr_shap_list_ir_5  1.969767,
#  5:       imbalanceRatio   entropy
#  0  lr_shap_list_ir_1  3.340222
#  1  lr_shap_list_ir_2  3.049014
#  2  lr_shap_list_ir_3  2.570827
#  3  lr_shap_list_ir_4  2.238986
#  4  lr_shap_list_ir_5  2.131104}

# %%
unique_feature_lists_df['index'] = 1

# %%
unique_feature_lists_df22 = calculate_unique_feature_lists_per_group(unique_feature_lists_df, 'index', "unique_feature_list")

# %%
unique_feature_lists_df22
# Out:
#      index                            unique_feature_list
# 0        1   (F12attr, C15attr, D4attr, B14attr, E11attr)
# 1        1   (F12attr, D16attr, D4attr, D28attr, F18attr)
# 2        1   (F12attr, D28attr, B14attr, D4attr, F18attr)
# 3        1  (F12attr, B26attr, B20attr, F24attr, F30attr)
# 4        1   (F12attr, F18attr, B14attr, D4attr, B20attr)
# ..     ...                                            ...
# 457      1  (F12attr, D28attr, A13attr, C27attr, D16attr)
# 458      1    (F12attr, F18attr, F6attr, E5attr, A25attr)
# 459      1   (F12attr, F18attr, D4attr, B20attr, D28attr)
# 460      1  (F18attr, F12attr, D28attr, B20attr, C15attr)
# 461      1    (F12attr, B14attr, F18attr, B2attr, D4attr)
#
# [462 rows x 2 columns]

# %% [markdown]
# ***
# ***
# ***
# ## Rand index
# features order analysis (top 5 OR top 20% {for features_amount > 25}) according to mean SHAP

# %%
sorted_orderScore[sorted_orderScore['Indicator']=='orderMean'][['imbalanceRatio', 'Subset', 'Sorted_Features']]
# Out:
#        imbalanceRatio                      Subset  \
# 0      shap_list_ir_1  shap_list_ir_1_subset_1000
# 3      shap_list_ir_1   shap_list_ir_1_subset_100
# 6      shap_list_ir_1   shap_list_ir_1_subset_101
# 9      shap_list_ir_1   shap_list_ir_1_subset_102
# 12     shap_list_ir_1   shap_list_ir_1_subset_103
# ...               ...                         ...
# 14985  shap_list_ir_5   shap_list_ir_5_subset_997
# 14988  shap_list_ir_5   shap_list_ir_5_subset_998
# 14991  shap_list_ir_5   shap_list_ir_5_subset_999
# 14994  shap_list_ir_5    shap_list_ir_5_subset_99
# 14997  shap_list_ir_5     shap_list_ir_5_subset_9
#
#                                          Sorted_Features
# 0      ['AGE', 'HYPERTENSION', 'DIABETES', 'CHRONIC_K...
# 3      ['AGE', 'HYPERTENSION', 'DIABETES', 'CHRONIC_K...
# 6      ['AGE', 'HYPERTENSION', 'DIABETES', 'SEX_FEMAL...
# 9      ['AGE', 'HYPERTENSION', 'DIABETES', 'ARTHROSIS...
# 12     ['AGE', 'HYPERTENSION', 'DIABETES', 'DEMENTIA'...
# ...                                                  ...
# 14985  ['AGE', 'HYPERTENSION', 'DIABETES', 'HEART_FAI...
# 14988  ['AGE', 'HYPERTENSION', 'DIABETES', 'HEART_FAI...
# 14991  ['AGE', 'HYPERTENSION', 'DIABETES', 'CHRONIC_K...
# 14994  ['AGE', 'HYPERTENSION', 'DIABETES', 'DEMENTIA'...
# 14997  ['AGE', 'HYPERTENSION', 'DIABETES', 'DEMENTIA'...
#
# [5000 rows x 3 columns]

# %%
# %%time
import pandas as pd
from sklearn.metrics.cluster import adjusted_rand_score


data = sorted_orderScore

# Initialize a dictionary to store results
results = []

# Iterate through each unique imbalanceRatio
for imbalance_ratio in data['imbalanceRatio'].unique():
    # Filter the DataFrame for the current imbalanceRatio
    subset_data = data[data['imbalanceRatio'] == imbalance_ratio]

    for _, row in subset_data.iterrows():
        # Extract the first 5 features from the Sorted_Features column
        sorted_features = eval(row['Sorted_Features'])  # Convert string representation of list to actual list
        top_5_features = sorted_features[:5]

        # Calculate Rand index (example calculation, modify as per actual use case)
        # Here, we're using random example data. Replace with your actual logic if needed.
        # Assume we compare top_5_features with a reference set of features
        reference_features = ['AGE', 'HYPERTENSION', 'DIABETES', 'CHRONIC_KIDNEY_DISEASE', 'HEART_FAILURE']
        rand_index = adjusted_rand_score(top_5_features, reference_features)

        # Append results
        results.append({
            'imbalanceRatio': imbalance_ratio,
            'Subset': row['Subset'],
            'RandIndex': rand_index,
            'Top5Features': top_5_features
        })

# Create a results DataFrame
results_df = pd.DataFrame(results)

# Save the results to a new CSV file
# results_df.to_csv("rand_index_results.csv", index=False)

# print("Rand index calculation completed. Results saved to 'rand_index_results.csv'.")
# Out:
# Wall time: 18.3 s

# %%
results_df
# Out:
#        imbalanceRatio                      Subset  RandIndex  \
# 0      shap_list_ir_1  shap_list_ir_1_subset_1000        1.0
# 1      shap_list_ir_1  shap_list_ir_1_subset_1000        1.0
# 2      shap_list_ir_1  shap_list_ir_1_subset_1000        1.0
# 3      shap_list_ir_1   shap_list_ir_1_subset_100        1.0
# 4      shap_list_ir_1   shap_list_ir_1_subset_100        1.0
# ...               ...                         ...        ...
# 14995  shap_list_ir_5    shap_list_ir_5_subset_99        1.0
# 14996  shap_list_ir_5    shap_list_ir_5_subset_99        1.0
# 14997  shap_list_ir_5     shap_list_ir_5_subset_9        1.0
# 14998  shap_list_ir_5     shap_list_ir_5_subset_9        1.0
# 14999  shap_list_ir_5     shap_list_ir_5_subset_9        1.0
#
#                                             Top5Features
# 0      [AGE, HYPERTENSION, DIABETES, CHRONIC_KIDNEY_D...
# 1      [AGE, DIABETES, HYPERTENSION, CHRONIC_KIDNEY_D...
# 2      [AGE, HYPERTENSION, DIABETES, CHRONIC_KIDNEY_D...
# 3      [AGE, HYPERTENSION, DIABETES, CHRONIC_KIDNEY_D...
# 4       [AGE, DIABETES, HYPERTENSION, ARTHROSIS, STROKE]
# ...                                                  ...
# 14995  [AGE, DIABETES, DEMENTIA, HEART_FAILURE, HYPER...
# 14996  [AGE, HYPERTENSION, DIABETES, DEMENTIA, CHRONI...
# 14997  [AGE, HYPERTENSION, DIABETES, DEMENTIA, CHRONI...
# 14998  [AGE, DIABETES, DEMENTIA, CHRONIC_KIDNEY_DISEA...
# 14999  [AGE, HYPERTENSION, DIABETES, DEMENTIA, CHRONI...
#
# [15000 rows x 4 columns]

# %%
results_df.describe()
# Out:
#        RandIndex
# count    15000.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0

# %% [markdown]
# # TEMP/Trash

# %% [markdown]
# ## Association rules
#
# https://towardsdatascience.com/association-rules-2-aa9a77241654

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

def calculate_association_rules(df, num_features, indicators):
    """
    Calculate association rules for the first `num_features` in the "Sorted_Features" column.

    Parameters:
        df (pd.DataFrame): Input DataFrame with columns 'Indicator', 'Sorted_Features', 'imbalanceRatio', and 'Subset'.
        num_features (int): Number of features to select for analysis from 'Sorted_Features'.
        indicators (list): List of indicators to filter on (e.g., ['orderMean', 'orderStd']).

    Returns:
        dict: A dictionary containing association rules for each subset and imbalance ratio.
    """
    # Filter the DataFrame by the specified indicators
    filtered_df = df[df['Indicator'].isin(indicators)]

    results = {}

    
    
    
    for (imbalance_ratio, subset), group in filtered_df.groupby(['imbalanceRatio', 'Subset']):
        # Extract the first `num_features` from "Sorted_Features" column
        features = group['Sorted_Features'].apply(lambda x: x[:num_features])

        # Create a one-hot encoded DataFrame for the features
        feature_set = pd.DataFrame(features.tolist()).stack().reset_index()
        feature_set.columns = ['row', 'feature_index', 'feature']
        one_hot = pd.crosstab(feature_set['row'], feature_set['feature']).astype(bool)

        # Apply the Apriori algorithm to find frequent itemsets
        frequent_itemsets = apriori(one_hot, min_support=0.1, use_colnames=True)

        # Generate association rules
        rules = association_rules(frequent_itemsets, metric='support', min_threshold=0.1,num_itemsets = 1000, support_only =True)

        # Store the rules in the results dictionary
        results[(imbalance_ratio, subset)] = rules

    return results

# # Example Usage
# # Assuming `sorted_orderScore` is your DataFrame
# # Define the number of features to analyze
# num_features = 5

# # Define the indicators to analyze
# indicators = ['orderMean', 'orderStd']

# # Call the function
# rules = calculate_association_rules(sorted_orderScore, num_features, indicators)

# # Print the rules for each (imbalanceRatio, Subset) combination
# for key, value in rules.items():
#     print(f"Rules for {key}:\n", value)
# Out:
# C:\Users\pilka\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Test dataset for imbalance ratio 1

# %%
ir1 = sorted_orderScore[sorted_orderScore['imbalanceRatio'] == 'shap_list_ir_1'].copy()
# Out:
# C:\Users\pilka\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# %%time
# Define the number of features to analyze
num_features = 5

# Define the indicators to analyze
indicators = ['orderMean']

# Call the function
rules = calculate_association_rules(ir1, num_features, indicators)

# Print the rules for each (imbalanceRatio, Subset) combination
for key, value in rules.items():
    print(f"Rules for {key}:\n", value)
# Out:
# C:\Users\pilka\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_1'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_10'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_100'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_1000'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_101'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_102'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_103'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_104'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_105'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_106'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_107'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_108'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_109'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_11'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_110'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_111'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_112'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_113'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_114'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_115'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_116'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_117'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_118'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_119'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_12'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_120'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_121'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_122'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_123'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_124'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_125'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_126'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_127'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_128'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_129'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_13'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_130'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_131'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_132'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_133'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_134'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_135'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_136'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_137'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_138'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_139'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_14'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_140'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_141'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_142'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_143'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_144'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_145'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_146'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_147'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_148'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_149'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_15'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_150'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_151'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_152'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_153'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_154'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_155'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_156'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_157'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_158'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_159'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_16'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_160'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_161'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_162'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_163'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_164'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_165'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_166'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_167'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_168'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_169'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_17'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_170'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_171'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_172'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_173'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_174'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_175'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_176'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_177'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_178'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_179'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_18'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_180'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_181'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_182'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_183'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_184'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_185'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_186'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_187'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_188'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_189'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_19'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_190'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_191'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_192'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_193'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_194'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_195'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_196'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_197'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_198'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_199'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_2'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_20'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_200'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_201'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_202'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_203'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_204'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_205'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_206'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_207'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_208'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_209'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_21'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_210'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_211'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_212'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_213'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_214'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_215'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_216'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_217'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_218'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_219'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_22'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_220'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_221'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_222'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_223'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_224'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_225'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_226'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_227'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_228'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_229'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_23'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_230'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_231'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_232'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_233'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_234'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_235'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_236'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_237'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_238'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_239'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_24'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_240'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_241'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_242'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_243'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_244'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_245'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_246'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_247'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_248'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_249'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_25'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_250'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_251'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_252'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_253'):
#  Empty DataFrame
# ...
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_948'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_949'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_95'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_950'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_951'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_952'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_953'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_954'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_955'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_956'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_957'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_958'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_959'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_96'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_960'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_961'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_962'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_963'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_964'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_965'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_966'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_967'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_968'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_969'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_97'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_970'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_971'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_972'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_973'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_974'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_975'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_976'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_977'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_978'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_979'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_98'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_980'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_981'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_982'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_983'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_984'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_985'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_986'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_987'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_988'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_989'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_99'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_990'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_991'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_992'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_993'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_994'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_995'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_996'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_997'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_998'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Rules for ('shap_list_ir_1', 'shap_list_ir_1_subset_999'):
#  Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
# Wall time: 19.4 s

# %%
rules
# Out:
# C:\Users\pilka\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

def calculate_support_confidence(df, num_features):
    """
    Calculate support and confidence for the first `num_features` in the "Sorted_Features" column.

    Parameters:
        df (pd.DataFrame): Input DataFrame with column 'Sorted_Features'.
        num_features (int): Number of features to select for analysis from 'Sorted_Features'.

    Returns:
        pd.DataFrame: A DataFrame containing the support and confidence of the most frequent names and their relations.
    """
    results = []

    for idx, row in df.iterrows():
        # Extract the first `num_features` from "Sorted_Features" column
        top_features = row['Sorted_Features'][:num_features]

        # Create a one-hot encoded DataFrame for the features
        feature_set = pd.DataFrame([top_features], columns=top_features).notna()

        # Apply the Apriori algorithm to find frequent itemsets
        frequent_itemsets = apriori(feature_set, min_support=0.1, use_colnames=True)

        # Generate association rules (only support and confidence)
        rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.1)
        rules = rules[['antecedents', 'consequents', 'support', 'confidence']]

        # Append rules to the results
        results.append(rules)

    # Combine all results into a single DataFrame
    combined_results = pd.concat(results, ignore_index=True)

    return combined_results

# # Example Usage
# # Assuming `sorted_orderScore` is your DataFrame
# # Define the number of features to analyze
# num_features = 5

# # Call the function
# support_confidence_results = calculate_support_confidence(sorted_orderScore, num_features)

# # Print the results
# print(support_confidence_results)
# Out:
# C:\Users\pilka\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ir1
# Out:
# C:\Users\pilka\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       imbalanceRatio                      Subset  Indicator  \
# 0     shap_list_ir_1  shap_list_ir_1_subset_1000  orderMean
# 1     shap_list_ir_1  shap_list_ir_1_subset_1000   orderStd
# 2     shap_list_ir_1  shap_list_ir_1_subset_1000   orderSum
# 3     shap_list_ir_1   shap_list_ir_1_subset_100  orderMean
# 4     shap_list_ir_1   shap_list_ir_1_subset_100   orderStd
# ...              ...                         ...        ...
# 2995  shap_list_ir_1    shap_list_ir_1_subset_99   orderStd
# 2996  shap_list_ir_1    shap_list_ir_1_subset_99   orderSum
# 2997  shap_list_ir_1     shap_list_ir_1_subset_9  orderMean
# 2998  shap_list_ir_1     shap_list_ir_1_subset_9   orderStd
# 2999  shap_list_ir_1     shap_list_ir_1_subset_9   orderSum
#
#                                         Sorted_Features
# 0     ['ARTHRITIS', 'CIRRHOSIS', 'OBESITY', 'DEPRESS...
# 1     ['ARTHRITIS', 'OBESITY', 'DEPRESSION', 'ARTHRO...
# 2     ['AGE', 'HYPERTENSION', 'DIABETES', 'CHRONIC_K...
# 3     ['ARTHRITIS', 'OSTEOPOROSIS', 'CIRRHOSIS', 'AS...
# 4     ['ARTHRITIS', 'SEX_FEMALE', 'OBESITY', 'COPD',...
# ...                                                 ...
# 2995  ['HEART_FAILURE', 'DEPRESSION', 'SEX_FEMALE', ...
# 2996  ['AGE', 'HYPERTENSION', 'DIABETES', 'OBESITY',...
# 2997  ['OSTEOPOROSIS', 'OBESITY', 'ASTHMA', 'ARTHRIT...
# 2998  ['OBESITY', 'SEX_FEMALE', 'OSTEOPOROSIS', 'ISC...
# 2999  ['AGE', 'HYPERTENSION', 'DIABETES', 'DEMENTIA'...
#
# [3000 rows x 4 columns]

# %%
# %%time
# Assuming `sorted_orderScore` is your DataFrame
# Define the number of features to analyze
num_features = 5

# Call the function
support_confidence_results = calculate_support_confidence(sorted_orderScore, num_features)
# Out:
# C:\Users\pilka\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-42-b6d21a41e088> in calculate_support_confidence(df, num_features)
#      21
#      22         # Create a one-hot encoded DataFrame for the features
# ---> 23         feature_set = pd.DataFrame([top_features], columns=top_features).notna()
#      24
#      25         # Apply the Apriori algorithm to find frequent itemsets
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     582                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     583                 else:
# --> 584                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     585             else:
#     586                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     204
#     205     # _prep_ndarray ensures that values.ndim == 2 at this point
# --> 206     index, columns = _get_axes(
#     207         values.shape[0], values.shape[1], index=index, columns=columns
#     208     )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _get_axes(N, K, index, columns)
#     464         columns = ibase.default_index(K)
#     465     else:
# --> 466         columns = ensure_index(columns)
#     467     return index, columns
#     468
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    5915             index_like = copy_func(index_like)
#    5916
# -> 5917     return Index(index_like)
#    5918
#    5919
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     370
#     371         elif data is None or is_scalar(data):
# --> 372             raise cls._scalar_data_error(data)
#     373         elif hasattr(data, "__array__"):
#     374             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, "['ART" was passed

# %%
support_confidence_results
# Out:
# C:\Users\pilka\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-1be98083ad44> in <module>
# ----> 1 support_confidence_results
#
# NameError: name 'support_confidence_results' is not defined

# %% [markdown]
# # Paper results

# %%
import pandas as pd
import scipy.stats as stats
import itertools
import os

# Lista de identificadores de datasets
dataset_identifiers = ["Covid_code", "Diabetes_code", "Satimage_code", "Satimage_code", "Satimage_code"]

# Ruta base de los archivos
base_path = "/Users/antonio/Desktop/Conference Paper SHAP Maciej actualizado/newResults"

# Lista para almacenar los rankings de cada dataset
all_rankings = []

for dataset in dataset_identifiers:
    file_path = os.path.join(base_path, dataset, "sorted_orderValuesScore.csv")

    # Cargar el dataset
    sorted_orderValuesScore = pd.read_csv(file_path)
    sorted_orderValuesScore.drop("Unnamed: 0", axis=1, inplace=True)
    sorted_orderValuesScore.columns = ['feature', 'shapMean', 'shapStd', 'shapSum', 'subset', 'imbalance_ratio']

    # Obtener valores únicos de IRs y features
    imbalance_ratios = sorted_orderValuesScore['imbalance_ratio'].unique()
    features = sorted_orderValuesScore['feature'].unique()

    # Diccionario para almacenar rankings
    rankings_dict = {feature: {} for feature in features}

    for feature in features:
        # Filtrar datos por la feature
        feature_data = sorted_orderValuesScore[sorted_orderValuesScore['feature'] == feature]

        # Calcular la media de shapMean por IR
        means = feature_data.groupby('imbalance_ratio')['shapMean'].mean().sort_values(ascending=False)

        # Matriz de significancia
        significance_matrix = pd.DataFrame(1.0, index=imbalance_ratios, columns=imbalance_ratios)

        # Pruebas t pareadas
        for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
            group1 = feature_data[feature_data['imbalance_ratio'] == ir1]['shapMean']
            group2 = feature_data[feature_data['imbalance_ratio'] == ir2]['shapMean']

            if len(group1) > 1 and len(group2) > 1:  # Asegurar suficientes datos
                stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)  # Welch’s t-test
            else:
                p_value = 1  # Asumir no diferencia si no hay suficientes datos

            # Almacenar p-valor
            significance_matrix.loc[ir1, ir2] = p_value
            significance_matrix.loc[ir2, ir1] = p_value

        # Asignar rankings iniciales basados en las medias
        ranking_values = {ir: rank + 1 for rank, ir in enumerate(means.index)}

        # Ajustar rankings si no hay diferencias significativas
        for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
            if significance_matrix.loc[ir1, ir2] >= 0.05:  # No diferencia significativa
                min_rank = min(ranking_values[ir1], ranking_values[ir2])
                ranking_values[ir1] = ranking_values[ir2] = min_rank

        rankings_dict[feature] = ranking_values

    # Convertir rankings a DataFrame
    ranking_table = pd.DataFrame(rankings_dict).T.fillna(0)

    # Reordenar las columnas por número de IR
    sorted_columns = sorted(ranking_table.columns, key=lambda x: int(x.split('_')[-1]))
    ranking_table = ranking_table[sorted_columns]
    
    # Agregar columna con nombre del dataset
    ranking_table["Dataset"] = dataset

    # Guardar resultados en la lista
    all_rankings.append(ranking_table)

# Concatenar todos los rankings en un solo DataFrame
final_ranking_table = pd.concat(all_rankings).reset_index().rename(columns={"index": "Feature"})

# Mostrar resultado
import ace_tools_open as tools
tools.display_dataframe_to_user(name="Combined Adjusted Ranking of the mean by IR for shapMeans", dataframe=final_ranking_table)
# Out:
# Combined Adjusted Ranking of the mean by IR for shapMeans
# <table id="itables_1c582910_1482_4837_a8c4_82ba203cf7cc" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Feature</th>
#       <th>shap_list_ir_1</th>
#       <th>shap_list_ir_2</th>
#       <th>shap_list_ir_3</th>
#       <th>shap_list_ir_4</th>
#       <th>shap_list_ir_5</th>
#       <th>Dataset</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_1c582910_1482_4837_a8c4_82ba203cf7cc:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["AGE", 1, 2, 3, 4, 5, "Covid_code"], ["SEX_FEMALE", 1, 2, 3, 4, 5, "Covid_code"], ["DIABETES", 5, 4, 3, 2, 1, "Covid_code"], ["HEART_FAILURE", 5, 4, 3, 2, 1, "Covid_code"], ["COPD", 1, 1, 3, 1, 1, "Covid_code"], ["HYPERTENSION", 1, 1, 2, 2, 2, "Covid_code"], ["DEPRESSION", 1, 2, 3, 4, 5, "Covid_code"], ["ISCHEMIC_HEART_DISEASE", 4, 4, 3, 2, 1, "Covid_code"], ["STROKE", 5, 4, 3, 2, 1, "Covid_code"], ["CHRONIC_KIDNEY_DISEASE", 5, 4, 3, 2, 1, "Covid_code"], ["CIRRHOSIS", 1, 2, 3, 3, 3, "Covid_code"], ["OSTEOPOROSIS", 1, 2, 3, 2, 2, "Covid_code"], ["ARTHROSIS", 4, 4, 2, 2, 1, "Covid_code"], ["ARTHRITIS", 1, 2, 3, 4, 5, "Covid_code"], ["DEMENTIA", 5, 4, 3, 2, 1, "Covid_code"], ["OBESITY", 1, 2, 3, 4, 5, "Covid_code"], ["ASTHMA", 1, 2, 3, 4, 5, "Covid_code"], ["Pregnancies", 1, 2, 3, 3, 3, "Diabetes_code"], ["Glucose", 5, 1, 1, 1, 1, "Diabetes_code"], ["BloodPressure", 1, 2, 3, 4, 5, "Diabetes_code"], ["SkinThickness", 1, 2, 3, 4, 5, "Diabetes_code"], ["Insulin", 1, 2, 3, 4, 4, "Diabetes_code"], ["BMI", 5, 2, 1, 1, 1, "Diabetes_code"], ["DiabetesPedigreeFunction", 1, 2, 3, 3, 5, "Diabetes_code"], ["Age", 1, 1, 1, 1, 1, "Diabetes_code"], ["Elevation", 1, 1, 3, 4, 5, "Forest_code"], ["Aspect", 1, 2, 2, 2, 2, "Forest_code"], ["Slope", 1, 2, 3, 3, 5, "Forest_code"], ["Horizontal_Distance_To_Hydrology", 5, 4, 2, 2, 1, "Forest_code"], ["Vertical_Distance_To_Hydrology", 4, 4, 3, 2, 1, "Forest_code"], ["Horizontal_Distance_To_Roadways", 1, 2, 3, 3, 3, "Forest_code"], ["Hillshade_9am", 1, 2, 3, 3, 3, "Forest_code"], ["Hillshade_Noon", 1, 2, 3, 4, 4, "Forest_code"], ["Hillshade_3pm", 1, 2, 2, 4, 4, "Forest_code"], ["Horizontal_Distance_To_Fire_Points", 1, 3, 3, 3, 1, "Forest_code"], ["Wilderness_Area3", 3, 5, 1, 1, 3, "Forest_code"], ["Wilderness_Area4", 5, 1, 2, 2, 4, "Forest_code"], ["Soil_Type1", 1, 1, 1, 1, 1, "Forest_code"], ["Soil_Type2", 1, 2, 2, 2, 2, "Forest_code"], ["Soil_Type3", 5, 4, 2, 1, 1, "Forest_code"], ["Soil_Type4", 1, 1, 1, 1, 1, "Forest_code"], ["Soil_Type5", 1, 2, 2, 2, 2, "Forest_code"], ["Soil_Type6", 1, 1, 1, 1, 1, "Forest_code"], ["Soil_Type10", 3, 1, 1, 1, 1, "Forest_code"], ["Soil_Type11", 1, 2, 2, 2, 2, "Forest_code"], ["Soil_Type13", 1, 1, 1, 1, 1, "Forest_code"], ["Soil_Type14", 1, 1, 1, 2, 1, "Forest_code"], ["Soil_Type16", 1, 2, 2, 2, 2, "Forest_code"], ["Soil_Type17", 4, 4, 3, 1, 1, "Forest_code"], ["Soil_Type32", 1, 1, 1, 1, 1, "Forest_code"], ["X1", 1, 2, 2, 4, 5, "Mammography_code"], ["X2", 1, 2, 3, 4, 5, "Mammography_code"], ["X3", 1, 1, 1, 4, 4, "Mammography_code"], ["X4", 5, 4, 3, 1, 1, "Mammography_code"], ["X5", 4, 4, 2, 2, 1, "Mammography_code"], ["X6", 1, 1, 1, 1, 1, "Mammography_code"], ["Aattr", 2, 4, 2, 2, 1, "Satimage_code"], ["Battr", 1, 2, 3, 3, 3, "Satimage_code"], ["Cattr", 1, 1, 1, 1, 1, "Satimage_code"], ["Dattr", 1, 1, 1, 1, 1, "Satimage_code"], ["Eattr", 1, 1, 1, 1, 1, "Satimage_code"], ["Fattr", 1, 2, 3, 3, 5, "Satimage_code"], ["A1attr", 1, 2, 3, 3, 3, "Satimage_code"], ["B2attr", 1, 1, 3, 3, 5, "Satimage_code"], ["C3attr", 1, 1, 1, 1, 1, "Satimage_code"], ["D4attr", 1, 1, 3, 3, 3, "Satimage_code"], ["E5attr", 1, 1, 1, 1, 1, "Satimage_code"], ["F6attr", 1, 1, 1, 1, 1, "Satimage_code"], ["A7attr", 5, 1, 1, 1, 1, "Satimage_code"], ["B8attr", 1, 1, 1, 1, 1, "Satimage_code"], ["C9attr", 1, 1, 1, 1, 1, "Satimage_code"], ["D10attr", 1, 1, 1, 1, 1, "Satimage_code"], ["E11attr", 5, 4, 1, 1, 1, "Satimage_code"], ["F12attr", 5, 1, 1, 1, 1, "Satimage_code"], ["A13attr", 4, 1, 1, 1, 1, "Satimage_code"], ["B14attr", 5, 2, 2, 2, 1, "Satimage_code"], ["C15attr", 4, 2, 1, 1, 1, "Satimage_code"], ["D16attr", 1, 2, 2, 2, 2, "Satimage_code"], ["E17attr", 1, 1, 1, 1, 1, "Satimage_code"], ["F18attr", 4, 2, 1, 1, 1, "Satimage_code"], ["A19attr", 1, 1, 1, 4, 4, "Satimage_code"], ["B20attr", 1, 2, 3, 4, 4, "Satimage_code"], ["C21attr", 1, 1, 1, 1, 1, "Satimage_code"], ["D22attr", 1, 1, 3, 4, 4, "Satimage_code"], ["E23attr", 1, 1, 1, 1, 1, "Satimage_code"], ["F24attr", 1, 2, 3, 3, 5, "Sa ...

# %%
import pandas as pd
import scipy.stats as stats
import itertools
import os

# Lista de identificadores de datasets
dataset_identifiers = ["Covid_code", "Diabetes_code", "Satimage_code", "Satimage_code", "Satimage_code"]

# Ruta base de los archivos
base_path = "/Users/antonio/Desktop/Conference Paper SHAP Maciej actualizado/newResults"

# Lista para almacenar los rankings de cada dataset
all_rankings = []

for dataset in dataset_identifiers:
    file_path = os.path.join(base_path, dataset, "sorted_orderValuesScore.csv")

    # Cargar el dataset
    sorted_orderValuesScore = pd.read_csv(file_path)
    sorted_orderValuesScore.drop("Unnamed: 0", axis=1, inplace=True)
    sorted_orderValuesScore.columns = ['feature', 'shapMean', 'shapStd', 'shapSum', 'subset', 'imbalance_ratio']

    # Obtener valores únicos de IRs y features
    imbalance_ratios = sorted_orderValuesScore['imbalance_ratio'].unique()
    features = sorted_orderValuesScore['feature'].unique()
    num_features = len(features)
    # Diccionario para almacenar rankings
    rankings_dict = {feature: {} for feature in features}

    for feature in features:
        # Filtrar datos por la feature
        feature_data = sorted_orderValuesScore[sorted_orderValuesScore['feature'] == feature]

        # Calcular la media de shapMean por IR
        means = feature_data.groupby('imbalance_ratio')['shapMean'].mean().sort_values(ascending=False)

        # Matriz de significancia
        significance_matrix = pd.DataFrame(1.0, index=imbalance_ratios, columns=imbalance_ratios)
        comparisons = itertools.combinations(imbalance_ratios, 2)
        comp_len = 10
        # Pruebas t pareadas
        for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
            group1 = feature_data[feature_data['imbalance_ratio'] == ir1]['shapMean']
            group2 = feature_data[feature_data['imbalance_ratio'] == ir2]['shapMean']

            if len(group1) > 1 and len(group2) > 1:  # Asegurar suficientes datos
                stat, p_value = stats.ttest_ind(group1, group2, equal_var=False)  # Welch’s t-test
                p_value *= comp_len
            else:
                p_value = 1  # Asumir no diferencia si no hay suficientes datos

            # Almacenar p-valor
            significance_matrix.loc[ir1, ir2] = p_value
            significance_matrix.loc[ir2, ir1] = p_value

        # Asignar rankings iniciales basados en las medias
        ranking_values = {ir: rank + 1 for rank, ir in enumerate(means.index)}

        # Ajustar rankings si no hay diferencias significativas
        for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
            if significance_matrix.loc[ir1, ir2] >= 0.05:  # No diferencia significativa
                min_rank = min(ranking_values[ir1], ranking_values[ir2])
                ranking_values[ir1] = ranking_values[ir2] = min_rank

        rankings_dict[feature] = ranking_values

    # Convertir rankings a DataFrame
    ranking_table = pd.DataFrame(rankings_dict).T.fillna(0)

    # Reordenar las columnas por número de IR
    sorted_columns = sorted(ranking_table.columns, key=lambda x: int(x.split('_')[-1]))
    ranking_table = ranking_table[sorted_columns]
    
    # Agregar columna con nombre del dataset
    ranking_table["Dataset"] = dataset

    # Guardar resultados en la lista
    all_rankings.append(ranking_table)

# Concatenar todos los rankings en un solo DataFrame
final_ranking_table = pd.concat(all_rankings).reset_index().rename(columns={"index": "Feature"})

# Mostrar resultado
import ace_tools_open as tools
tools.display_dataframe_to_user(name="Combined Adjusted Ranking of the mean by IR for shapMeans", dataframe=final_ranking_table)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/bh/xp4_lj757fl9gg_xk2k69gk00000gn/T/ipykernel_9822/1295184482.py in <module>
#      45
#      46             if len(group1) > 1 and len(group2) > 1:  # Asegurar suficientes datos
# ---> 47                 stat, p_value = stats.mannwhitneyu(group1, group2, equal_var=False)  # Welch’s t-test
#      48                 p_value *= comp_len
#      49             else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_axis_nan_policy.py in axis_nan_policy_wrapper(***failed resolving arguments***)
#     529                 if sentinel:
#     530                     samples = _remove_sentinel(samples, paired, sentinel)
# --> 531                 res = hypotest_fun_out(*samples, **kwds)
#     532                 res = result_to_tuple(res)
#     533                 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# TypeError: mannwhitneyu() got an unexpected keyword argument 'equal_var'

# %%
comparisons = itertools.combinations(imbalance_ratios, 2)
for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
    print(ir1)
# Out:
# shap_list_ir_2
# shap_list_ir_2
# shap_list_ir_2
# shap_list_ir_2
# shap_list_ir_4
# shap_list_ir_4
# shap_list_ir_4
# shap_list_ir_3
# shap_list_ir_3
# shap_list_ir_1

# %%
medias = final_ranking_table.iloc[:, 1:-1].mean()

print(medias)
# Out:
# shap_list_ir_1    1.695652
# shap_list_ir_2    1.684783
# shap_list_ir_3    1.641304
# shap_list_ir_4    1.706522
# shap_list_ir_5    1.706522
# dtype: float64

# %%
# Suponiendo que final_ranking_table ya tiene las columnas 'shap_list_ir_1' a 'shap_list_ir_5'
# Si estas columnas vienen de los nombres de las IR en el CSV, asegúrate de que correspondan.
# En caso de que tengan otro nombre, ajusta la lista de columnas.

# Lista de columnas a promediar:

cols_ir = [col for col in final_ranking_table.columns if col.startswith("shap_list_ir_")]

# Calcular la media por dataset:
mean_by_dataset = final_ranking_table.groupby("Dataset")[cols_ir].mean()

# Calcular la media global (todos los datasets juntos):
mean_all = final_ranking_table[cols_ir].mean().to_frame().T
mean_all.index = ["All_Datasets"]

# Concatenar ambos resultados en un solo dataframe:
result_df = pd.concat([mean_by_dataset, mean_all])

# Mostrar el resultado:
print(result_df)
# Out:
#                   shap_list_ir_1  shap_list_ir_2  shap_list_ir_3  \
# Covid_code              2.529412        2.705882        2.882353
# Diabetes_code           2.000000        1.750000        2.250000
# Forest_code             1.880000        2.120000        2.000000
# Mammography_code        2.166667        2.333333        2.000000
# Satimage_code           1.777778        1.527778        1.583333
# All_Datasets            1.989130        1.978261        2.021739
#
#                   shap_list_ir_4  shap_list_ir_5
# Covid_code              2.705882        2.647059
# Diabetes_code           2.625000        3.125000
# Forest_code             2.040000        2.120000
# Mammography_code        2.666667        2.833333
# Satimage_code           1.722222        2.000000
# All_Datasets            2.130435        2.304348

# %%
import numpy as np
import matplotlib.pyplot as plt

num_irs = 5
shap_list_labels = ['1:49', '1:19', '1:9', '3:17', '1:4']

rank_colors = {1: 'blue', 2: 'green', 3: 'yellow', 4: 'orange', 5: 'red'}
mismatch_color = 'white'  # Color for non-matching ranks

# Filtrar solo columnas de IRs
ir_columns = [col for col in final_ranking_table.columns if col not in ["Feature", "Dataset"]]
ranking_table_filtered = final_ranking_table[ir_columns]

fig, axes = plt.subplots(num_irs, num_irs, figsize=(25, 25))

num_variables = ranking_table_filtered.shape[0]

for i in range(num_irs):
    for j in range(num_irs):
        ax = axes[i, j]

        if j < i:
            ax.axis("off")
            continue

        if i == j:
            values, counts = np.unique(ranking_table_filtered.iloc[:, i].dropna().astype(int), return_counts=True)
            colors = [rank_colors.get(v, mismatch_color) for v in values]
        else:
            matching_counts = {rank: 0 for rank in rank_colors.keys()}

            for var in range(num_variables):
                rank_i = ranking_table_filtered.iloc[var, i]
                rank_j = ranking_table_filtered.iloc[var, j]
                if rank_i == rank_j:
                    matching_counts[rank_i] += 1

            values = [rank for rank, count in matching_counts.items() if count > 0]
            counts = [count / num_variables for rank, count in matching_counts.items() if count > 0]

            mismatch_proportion = 1 - sum(counts)
            if mismatch_proportion > 0:
                values.append(0)
                counts.append(mismatch_proportion)

            colors = [rank_colors.get(v, mismatch_color) for v in values]

        if len(values) > 0:
            ax.pie(counts, labels=None, autopct='%1.1f%%', colors=colors, startangle=90,
                   textprops={'fontsize': 15}, pctdistance=1.45)
        else:
            ax.axis("off")

        if j == i:
            ax.set_ylabel(shap_list_labels[i], rotation=0, labelpad=50, fontsize=20, ha='right', va='center')

# Añadir 'IR' en la parte superior del eje X
for ax, col in zip(axes[0], shap_list_labels):
    ax.set_title(col, fontsize=20, pad=30)

fig.text(0.5, 0.98, 'IR', ha='center', va='center', fontsize=22, fontweight='bold')

# Añadir 'IR' en la parte izquierda del eje Y
fig.text(0.02, 0.5, 'IR', ha='center', va='center', rotation=90, fontsize=22, fontweight='bold')

# Leyenda
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=15) for color in rank_colors.values()]
handles.append(plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='white', markersize=15))  # "No Match"

labels = [f"Rank {k}" for k in rank_colors.keys()] + ["No Match"]
fig.legend(handles, labels, title="Rank Values", loc="lower left", bbox_to_anchor=(0.3, 0.2), fontsize=21, title_fontsize=25)

plt.tight_layout()

# Guardar imagen con 600 dpi
plt.savefig("ranking_heatmap_bonf.png", dpi=600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import scipy.stats as stats
import itertools
import os

# Lista de identificadores de datasets
dataset_identifiers = ["Covid_code", "Diabetes_code", "Satimage_code", "Satimage_code", "Satimage_code"]

# Ruta base de los archivos
base_path = "/Users/antonio/Desktop/Conference Paper SHAP Maciej actualizado/newResults"

# Lista para almacenar los rankings de cada dataset
all_rankings_std = []

for dataset in dataset_identifiers:
    file_path = os.path.join(base_path, dataset, "sorted_orderValuesScore.csv")

    # Cargar el dataset
    sorted_orderValuesScore = pd.read_csv(file_path)
    sorted_orderValuesScore.drop("Unnamed: 0", axis=1, inplace=True)
    sorted_orderValuesScore.columns = ['feature', 'shapMean', 'shapStd', 'shapSum', 'subset', 'imbalance_ratio']

    # Obtener valores únicos de IRs y features
    imbalance_ratios = sorted_orderValuesScore['imbalance_ratio'].unique()
    features = sorted_orderValuesScore['feature'].unique()
    features_num = len(features)
    # Diccionario para almacenar rankings
    rankings_std_dict = {feature: {} for feature in features}

    for feature in features:
        # Filtrar datos por la feature
        feature_data = sorted_orderValuesScore[sorted_orderValuesScore['feature'] == feature]

        # Calcular la desviación estándar de shapMean por IR
        std_devs = feature_data.groupby('imbalance_ratio')['shapMean'].std().sort_values(ascending=False)

        # Matriz de significancia
        significance_matrix = pd.DataFrame(1.0, index=imbalance_ratios, columns=imbalance_ratios)

        # Pruebas de Levene para comparar varianzas
        for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
            group1 = feature_data[feature_data['imbalance_ratio'] == ir1]['shapMean']
            group2 = feature_data[feature_data['imbalance_ratio'] == ir2]['shapMean']

            if len(group1) > 1 and len(group2) > 1:  # Asegurar suficientes datos
                stat, p_value = stats.levene(group1, group2, center='median')  # Levene’s test
                p_value *= 10
            else:
                p_value = 1  # Asumir no diferencia si no hay suficientes datos

            # Almacenar p-valor
            significance_matrix.loc[ir1, ir2] = p_value
            significance_matrix.loc[ir2, ir1] = p_value

        # Asignar rankings iniciales basados en las desviaciones estándar
        ranking_values = {ir: rank + 1 for rank, ir in enumerate(std_devs.index)}

        # Ajustar rankings si no hay diferencias significativas
        for ir1, ir2 in itertools.combinations(imbalance_ratios, 2):
            if significance_matrix.loc[ir1, ir2] >= 0.05:  # No diferencia significativa
                min_rank = min(ranking_values[ir1], ranking_values[ir2])
                ranking_values[ir1] = ranking_values[ir2] = min_rank

        rankings_std_dict[feature] = ranking_values

    # Convertir rankings a DataFrame
    ranking_std_table = pd.DataFrame(rankings_std_dict).T.fillna(0)

    # Agregar columna con nombre del dataset
    ranking_std_table["Dataset"] = dataset

    # Guardar resultados en la lista
    all_rankings_std.append(ranking_std_table)

# Concatenar todos los rankings en un solo DataFrame
final_ranking_std_table = pd.concat(all_rankings_std).reset_index().rename(columns={"index": "Feature"})

# Mostrar resultado
import ace_tools_open as tools
tools.display_dataframe_to_user(name="Combined Adjusted Ranking of the variance by IR for shapMeans", dataframe=final_ranking_std_table)
# Out:
# Combined Adjusted Ranking of the variance by IR for shapMeans
# <table id="itables_68fd8301_acc1_4d8f_aafc_ddfdc51874e1" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Feature</th>
#       <th>shap_list_ir_1</th>
#       <th>shap_list_ir_2</th>
#       <th>shap_list_ir_3</th>
#       <th>shap_list_ir_4</th>
#       <th>shap_list_ir_5</th>
#       <th>Dataset</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_68fd8301_acc1_4d8f_aafc_ddfdc51874e1:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["AGE", 1, 2, 3, 4, 4, "Covid_code"], ["SEX_FEMALE", 1, 2, 3, 4, 5, "Covid_code"], ["DIABETES", 1, 2, 3, 4, 5, "Covid_code"], ["HEART_FAILURE", 1, 2, 3, 4, 5, "Covid_code"], ["COPD", 1, 2, 3, 3, 5, "Covid_code"], ["HYPERTENSION", 1, 2, 3, 4, 5, "Covid_code"], ["DEPRESSION", 1, 2, 3, 4, 5, "Covid_code"], ["ISCHEMIC_HEART_DISEASE", 1, 2, 3, 4, 5, "Covid_code"], ["STROKE", 1, 2, 3, 4, 5, "Covid_code"], ["CHRONIC_KIDNEY_DISEASE", 1, 2, 3, 4, 5, "Covid_code"], ["CIRRHOSIS", 1, 2, 3, 4, 5, "Covid_code"], ["OSTEOPOROSIS", 1, 2, 3, 4, 5, "Covid_code"], ["ARTHROSIS", 1, 2, 3, 4, 5, "Covid_code"], ["ARTHRITIS", 1, 2, 3, 4, 5, "Covid_code"], ["DEMENTIA", 1, 2, 3, 4, 5, "Covid_code"], ["OBESITY", 1, 2, 3, 4, 5, "Covid_code"], ["ASTHMA", 1, 2, 3, 4, 5, "Covid_code"], ["Pregnancies", 1, 1, 1, 1, 1, "Diabetes_code"], ["Glucose", 1, 1, 3, 4, 4, "Diabetes_code"], ["BloodPressure", 1, 2, 2, 2, 5, "Diabetes_code"], ["SkinThickness", 1, 1, 3, 3, 3, "Diabetes_code"], ["Insulin", 1, 1, 3, 3, 3, "Diabetes_code"], ["BMI", 1, 1, 3, 3, 3, "Diabetes_code"], ["DiabetesPedigreeFunction", 1, 1, 1, 1, 1, "Diabetes_code"], ["Age", 1, 1, 1, 1, 5, "Diabetes_code"], ["Elevation", 1, 2, 3, 3, 3, "Forest_code"], ["Aspect", 1, 1, 1, 1, 1, "Forest_code"], ["Slope", 1, 1, 3, 3, 3, "Forest_code"], ["Horizontal_Distance_To_Hydrology", 1, 1, 3, 3, 3, "Forest_code"], ["Vertical_Distance_To_Hydrology", 1, 2, 2, 2, 2, "Forest_code"], ["Horizontal_Distance_To_Roadways", 1, 2, 2, 2, 2, "Forest_code"], ["Hillshade_9am", 1, 2, 2, 2, 2, "Forest_code"], ["Hillshade_Noon", 1, 1, 1, 1, 1, "Forest_code"], ["Hillshade_3pm", 1, 2, 2, 2, 2, "Forest_code"], ["Horizontal_Distance_To_Fire_Points", 1, 2, 2, 2, 2, "Forest_code"], ["Wilderness_Area3", 1, 1, 1, 1, 1, "Forest_code"], ["Wilderness_Area4", 1, 1, 1, 1, 1, "Forest_code"], ["Soil_Type1", 1, 1, 1, 1, 1, "Forest_code"], ["Soil_Type2", 1, 2, 2, 2, 2, "Forest_code"], ["Soil_Type3", 1, 2, 2, 2, 2, "Forest_code"], ["Soil_Type4", 1, 1, 1, 1, 1, "Forest_code"], ["Soil_Type5", 1, 2, 2, 2, 2, "Forest_code"], ["Soil_Type6", 1, 1, 1, 1, 1, "Forest_code"], ["Soil_Type10", 1, 2, 2, 2, 5, "Forest_code"], ["Soil_Type11", 1, 2, 2, 2, 2, "Forest_code"], ["Soil_Type13", 1, 1, 1, 1, 1, "Forest_code"], ["Soil_Type14", 1, 1, 1, 1, 1, "Forest_code"], ["Soil_Type16", 1, 2, 2, 2, 2, "Forest_code"], ["Soil_Type17", 1, 2, 2, 2, 2, "Forest_code"], ["Soil_Type32", 1, 1, 1, 1, 1, "Forest_code"], ["X1", 1, 2, 3, 4, 5, "Mammography_code"], ["X2", 1, 2, 3, 3, 3, "Mammography_code"], ["X3", 1, 1, 3, 4, 4, "Mammography_code"], ["X4", 1, 2, 2, 2, 5, "Mammography_code"], ["X5", 1, 2, 3, 4, 5, "Mammography_code"], ["X6", 1, 2, 3, 4, 4, "Mammography_code"], ["Aattr", 1, 2, 2, 2, 2, "Satimage_code"], ["Battr", 1, 1, 1, 1, 1, "Satimage_code"], ["Cattr", 1, 1, 1, 1, 1, "Satimage_code"], ["Dattr", 1, 1, 1, 1, 1, "Satimage_code"], ["Eattr", 1, 1, 1, 1, 1, "Satimage_code"], ["Fattr", 1, 1, 1, 1, 1, "Satimage_code"], ["A1attr", 1, 2, 3, 3, 3, "Satimage_code"], ["B2attr", 1, 1, 3, 3, 3, "Satimage_code"], ["C3attr", 1, 1, 1, 4, 5, "Satimage_code"], ["D4attr", 1, 1, 3, 3, 3, "Satimage_code"], ["E5attr", 1, 1, 1, 1, 1, "Satimage_code"], ["F6attr", 1, 1, 1, 1, 5, "Satimage_code"], ["A7attr", 1, 1, 3, 3, 5, "Satimage_code"], ["B8attr", 1, 1, 1, 1, 1, "Satimage_code"], ["C9attr", 1, 1, 1, 4, 4, "Satimage_code"], ["D10attr", 1, 1, 1, 1, 1, "Satimage_code"], ["E11attr", 1, 2, 3, 3, 5, "Satimage_code"], ["F12attr", 1, 1, 3, 3, 3, "Satimage_code"], ["A13attr", 1, 1, 1, 1, 1, "Satimage_code"], ["B14attr", 1, 1, 1, 1, 1, "Satimage_code"], ["C15attr", 1, 1, 3, 3, 3, "Satimage_code"], ["D16attr", 1, 2, 2, 2, 2, "Satimage_code"], ["E17attr", 1, 1, 1, 1, 1, "Satimage_code"], ["F18attr", 1, 1, 1, 1, 1, "Satimage_code"], ["A19attr", 1, 1, 3, 3, 5, "Satimage_code"], ["B20attr", 1, 2, 3, 4, 4, "Satimage_code"], ["C21attr", 1, 1, 1, 1, 1, "Satimage_code"], ["D22attr", 1, 1, 1, 4, 4, "Satimage_code"], ["E23attr", 1, 1, 3, 3, 5, "Satimage_code"], ["F24attr", 1, 2, 3, 3, 3, "Sa ...

# %%
# Suponiendo que final_ranking_table ya tiene las columnas 'shap_list_ir_1' a 'shap_list_ir_5'
# Si estas columnas vienen de los nombres de las IR en el CSV, asegúrate de que correspondan.
# En caso de que tengan otro nombre, ajusta la lista de columnas.

# Lista de columnas a promediar:

cols_ir = [col for col in final_ranking_std_table.columns if col.startswith("shap_list_ir_")]

# Calcular la media por dataset:
mean_by_dataset = final_ranking_std_table.groupby("Dataset")[cols_ir].mean()

# Calcular la media global (todos los datasets juntos):
mean_all = final_ranking_std_table[cols_ir].mean().to_frame().T
mean_all.index = ["All_Datasets"]

# Concatenar ambos resultados en un solo dataframe:
result_df = pd.concat([mean_by_dataset, mean_all])

# Mostrar el resultado:
print(result_df)
# Out:
#                   shap_list_ir_1  shap_list_ir_2  shap_list_ir_3  \
# Covid_code                   1.0        2.000000        3.000000
# Diabetes_code                1.0        1.500000        2.750000
# Forest_code                  1.0        1.640000        2.280000
# Mammography_code             1.0        1.833333        2.833333
# Satimage_code                1.0        1.500000        2.722222
# All_Datasets                 1.0        1.652174        2.663043
#
#                   shap_list_ir_4  shap_list_ir_5
# Covid_code              4.000000        5.000000
# Diabetes_code           3.125000        3.750000
# Forest_code             2.280000        2.520000
# Mammography_code        3.500000        4.833333
# Satimage_code           3.166667        4.277778
# All_Datasets            3.097826        3.923913

# %%
import numpy as np
import matplotlib.pyplot as plt

num_irs = 5
shap_list_labels = ['1:49', '1:19', '1:9', '3:17', '1:4']

rank_colors = {1: 'blue', 2: 'green', 3: 'yellow', 4: 'orange', 5: 'red'}
mismatch_color = 'white'  # Color para valores no coincidentes


# Filtrar solo columnas de IRs
ir_columns = [col for col in final_ranking_std_table.columns if col not in ["Feature", "Dataset"]]
ranking_std_table_filtered = final_ranking_std_table[ir_columns]

fig, axes = plt.subplots(num_irs, num_irs, figsize=(25, 25))

num_variables = ranking_std_table_filtered.shape[0]

for i in range(num_irs):
    for j in range(num_irs):
        ax = axes[i, j]

        if j < i:
            ax.axis("off")
            continue

        if i == j:
            values, counts = np.unique(ranking_std_table_filtered.iloc[:, i].dropna().astype(int), return_counts=True)
            colors = [rank_colors.get(v, mismatch_color) for v in values]
        else:
            matching_counts = {rank: 0 for rank in rank_colors.keys()}

            for var in range(num_variables):
                rank_i = ranking_std_table_filtered.iloc[var, i]
                rank_j = ranking_std_table_filtered.iloc[var, j]

                if rank_i == rank_j:
                    matching_counts[rank_i] += 1

            values = [rank for rank, count in matching_counts.items() if count > 0]
            counts = [count / num_variables for rank, count in matching_counts.items() if count > 0]

            mismatch_proportion = 1 - sum(counts)
            if mismatch_proportion > 0:
                values.append(0)
                counts.append(mismatch_proportion)

            colors = [rank_colors.get(v, mismatch_color) for v in values]

        if len(values) > 0:
            ax.pie(counts, labels=None, autopct='%1.1f%%', colors=colors, startangle=90,
                   textprops={'fontsize': 15}, pctdistance=1.45)
        else:
            ax.axis("off")

        if j == i:
            ax.set_ylabel(shap_list_labels[i], rotation=0, labelpad=50, fontsize=20, ha='right', va='center')

# Añadir 'IR' en la parte superior del eje X
for ax, col in zip(axes[0], shap_list_labels):
    ax.set_title(col, fontsize=20, pad=30)

fig.text(0.5, 0.98, 'IR', ha='center', va='center', fontsize=22, fontweight='bold')

# Añadir 'IR' en la parte izquierda del eje Y
fig.text(0.02, 0.5, 'IR', ha='center', va='center', rotation=90, fontsize=22, fontweight='bold')

# Leyenda
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=15) for color in rank_colors.values()]
handles.append(plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='white', markersize=15))  # "No Match"

labels = [f"Rank {k}" for k in rank_colors.keys()] + ['No Match']
fig.legend(handles, labels, title="Rank Values", loc="lower left", bbox_to_anchor=(0.3, 0.2), fontsize=21, title_fontsize=25)

plt.tight_layout()

# Guardar imagen con 600 dpi
plt.savefig("variance_ranking_heatmap_bonf.png", dpi=600, bbox_inches='tight')
plt.show()

# %%
file_path = "/Users/antonio/Desktop/Conference Paper SHAP Maciej actualizado/Diabetes/metrics_summary.parquet"

# Cargar el archivo Parquet en un DataFrame de pandas
df = pd.read_parquet(file_path)
print(df)
# Out:
#                  Dataset  Balanced Accuracy  Accuracy  Cohen's Kappa  \
# 0      IR_1_subset_1.csv           1.000000  1.000000       1.000000
# 1      IR_1_subset_2.csv           1.000000  1.000000       1.000000
# 2      IR_1_subset_3.csv           1.000000  1.000000       1.000000
# 3      IR_1_subset_4.csv           1.000000  1.000000       1.000000
# 4      IR_1_subset_5.csv           0.949000  0.996078       0.898000
# ..                   ...                ...       ...            ...
# 795  IR_5_subset_156.csv           0.882353  0.894118       0.697987
# 796  IR_5_subset_157.csv           0.894608  0.890196       0.696970
# 797  IR_5_subset_158.csv           0.887255  0.890196       0.692982
# 798  IR_5_subset_159.csv           0.882353  0.900000       0.709898
# 799  IR_5_subset_160.csv           0.905637  0.890196       0.702760
#
#      F1-Score   ROC-AUC
# 0    1.000000  1.000000
# 1    1.000000  1.000000
# 2    1.000000  1.000000
# 3    1.000000  1.000000
# 4    0.900000  0.999800
# ..        ...       ...
# 795  0.765217  0.969435
# 796  0.766667  0.964821
# 797  0.762712  0.958333
# 798  0.773333  0.958453
# 799  0.772358  0.968642
#
# [800 rows x 6 columns]

# %%
import pandas as pd

# Cargar el DataFrame desde el archivo Parquet
file_path = "/Users/antonio/Desktop/Conference Paper SHAP Maciej actualizado/Diabetes/metrics_summary.parquet"
df = pd.read_parquet(file_path)

# Extraer la parte "IR_x" del nombre en la columna 'Dataset'
df['IR'] = df['Dataset'].str.extract(r'(IR_\d+)', expand=False)

# Agrupar por la nueva columna 'IR' y calcular la media de las métricas
grouped_means = df.groupby('IR')[['Balanced Accuracy', 'Accuracy', "Cohen's Kappa", 'F1-Score', 'ROC-AUC']].mean().reset_index()

# Mostrar el resultado
print(grouped_means)
# Out:
#      IR  Balanced Accuracy  Accuracy  Cohen's Kappa  F1-Score   ROC-AUC
# 0  IR_1           0.994875  0.998358       0.961829  0.962652  0.999860
# 1  IR_2           0.968001  0.978150       0.807192  0.818298  0.996096
# 2  IR_3           0.927499  0.934792       0.705617  0.740981  0.982918
# 3  IR_4           0.905351  0.910637       0.691052  0.743008  0.972751
# 4  IR_5           0.888794  0.888725       0.691434  0.762007  0.962870

# %%
import pandas as pd
import numpy as np
from scipy import stats
import scipy
# Lista de datasets y ruta base
datasets = ['COVID', 'Diabetes', 'Satimage', 'Satimage', 'Satimage']
base_path = "/Users/antonio/Desktop/Conference Paper SHAP Maciej actualizado"

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

# Métricas a analizar
metrics = ["Balanced Accuracy"]

# Diccionario para almacenar los DataFrames de medias por IR para cada dataset
ir_means_dict = {}

# Lista para almacenar estadísticas globales (mean e intervalo de confianza)
overall_stats = []

for dset in datasets:
    file_path = f"{base_path}/{dset}/metrics_summary.parquet"
    df = pd.read_parquet(file_path)
    df['Dataset'] = df['Dataset'].str.upper()
    # Extraer el IR de la columna 'Dataset' (ejemplo: 'IR_1')
    df['IR'] = df['Dataset'].str.extract(r'(IR_\d+)', expand=False)
    
    # Agrupar por IR y calcular la media de cada métrica
    grouped_means = df.groupby('IR')[metrics].mean().reset_index()
    ir_means_dict[dset] = grouped_means
    
    # Calcular estadísticas globales (sin distinguir IR)
    stats_dict = {"Dataset": dset}
    for metric in metrics:
        data = df[metric].to_numpy()
        mean_val = data.mean()
        std_val = data.std(ddof=1)
        n = len(data)
        mean_val,ci_lower, ci_upper = mean_confidence_interval(data)
        # Calcular intervalo de confianza al 95%
        #ci_lower, ci_upper = stats.t.interval(0.95, n-1, loc=mean_val, scale=std_val/np.sqrt(n))
        
        stats_dict[f"{metric} Mean"] = mean_val
        stats_dict[f"{metric} CI Lower"] = ci_lower
        stats_dict[f"{metric} CI Upper"] = ci_upper
        
    overall_stats.append(stats_dict)

# Crear DataFrame con estadísticas globales
overall_stats_df = pd.DataFrame(overall_stats)

# Mostrar los promedios por IR para cada dataset
print("Medias por IR para cada dataset:")
for dset, grouped_df in ir_means_dict.items():
    print(f"\nDataset: {dset}")
    print(grouped_df)

# Mostrar la tabla de estadísticas globales (media e intervalo de confianza)
print("\nEstadísticas globales (sin agrupar por IR):")
print(overall_stats_df)
# Out:
# Medias por IR para cada dataset:
#
# Dataset: COVID
#      IR  Balanced Accuracy
# 0  IR_1           0.910412
# 1  IR_2           0.903099
# 2  IR_3           0.899544
# 3  IR_4           0.898092
# 4  IR_5           0.896919
#
# Dataset: Diabetes
#      IR  Balanced Accuracy
# 0  IR_1           0.994875
# 1  IR_2           0.968001
# 2  IR_3           0.927499
# 3  IR_4           0.905351
# 4  IR_5           0.888794
#
# Dataset: Forest
#      IR  Balanced Accuracy
# 0  IR_1           0.939966
# 1  IR_2           0.930882
# 2  IR_3           0.926293
# 3  IR_4           0.924093
# 4  IR_5           0.922923
#
# Dataset: Mammography
#      IR  Balanced Accuracy
# 0  IR_1           0.978899
# 1  IR_2           0.961631
# 2  IR_3           0.951006
# 3  IR_4           0.945068
# 4  IR_5           0.942243
#
# Dataset: Satimage
#      IR  Balanced Accuracy
# 0  IR_1           0.962193
# 1  IR_2           0.938396
# 2  IR_3           0.917721
# 3  IR_4           0.910414
# 4  IR_5           0.905738
#
# Estadísticas globales (sin agrupar por IR):
#        Dataset  Balanced Accuracy Mean  Balanced Accuracy CI Lower  \
# 0        COVID                0.901613                    0.901367
# 1     Diabetes                0.936904                    0.933952
# 2       Forest                0.928832                    0.928187
# 3  Mammography                0.955769                    0.954360
# 4     Satimage                0.926893                    0.924983
#
#    Balanced Accuracy CI Upper
# 0                    0.901860
# 1                    0.939856
# 2                    0.929476
# 3                    0.957179
# 4                    0.928802

# %%
file_path = f"{base_path}/COVID/metrics_summary.parquet"

df = pd.read_parquet(file_path)
df['Dataset'] = df['Dataset'].str.upper()
df['IR'] = df['Dataset'].str.extract(r'(IR_\d+)', expand=False)
print(df)
print(df['Balanced Accuracy'].mean())
# Out:
# 0.9016132675514064
